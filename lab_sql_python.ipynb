# %%
import psycopg2
from psycopg2 import OperationalError, errorcodes, errors

import pandas as pd

# %%
df_api = pd.read_csv('api_foursquare.csv', index_col= 0)

# %%
df_aemet = pd.read_csv('df_aemet_final.csv', index_col= 0)

# %%
df_municipios = pd.read_csv('municipios.csv', index_col=0)

# %%
df_municipios.head()
# Out:
#    acebeda-la     ajalvir  alameda-del-valle    alamo-el  alcala-de-henares  \
# 0  41.0869583  40.5342302         40.9177178  40.2307296         40.4818396
# 1   -3.624399  -3.4807818         -3.8438216  -3.9905893         -3.3644973
# 2  La Acebeda     Ajalvir  Alameda del Valle    El Álamo  Alcalá de Henares
#
#    alcobendas    alcorcon  aldea-del-fresno      algete   alpedrete  ...  \
# 0  40.5400082  40.3492998        40.3215212  40.5961652  40.6599005  ...
# 1  -3.6358494  -3.8284295          -4.19936  -3.4974246  -4.0251223  ...
# 2  Alcobendas    Alcorcón  Aldea del Fresno      Algete   Alpedrete  ...
#
#    villamanta  villamantilla  villanueva-de-la-canada  \
# 0  40.2990939     40.3421033               40.4472106
# 1  -4.1090399     -4.1300303                -4.002795
# 2  Villamanta  Villamantilla  Villanueva de la Cañada
#
#    villanueva-del-pardillo  villanueva-de-perales  villar-del-olmo  \
# 0               40.4949232             40.3466066       40.3364465
# 1               -3.9600065             -4.1012616       -3.2355624
# 2  Villanueva del Pardillo  Villanueva de Perales  Villar del Olmo
#
#    villarejo-de-salvanes  villaviciosa-de-odon  villavieja-del-lozoya  \
# 0             40.1683582            40.3573787             41.0063622
# 1             -3.2738764            -3.9002334             -3.6716291
# 2  Villarejo de Salvanés  Villaviciosa de Odón  Villavieja del Lozoya
#
#     zarzalejo
# 0  40.5483016
# 1  -4.1815899
# 2   Zarzalejo
#
# [3 rows x 176 columns]

# %%
df_municipios=df_municipios.T

# %%
df_municipios
# Out:
#                                 0           1                      2
# acebeda-la             41.0869583   -3.624399             La Acebeda
# ajalvir                40.5342302  -3.4807818                Ajalvir
# alameda-del-valle      40.9177178  -3.8438216      Alameda del Valle
# alamo-el               40.2307296  -3.9905893               El Álamo
# alcala-de-henares      40.4818396  -3.3644973      Alcalá de Henares
# ...                           ...         ...                    ...
# villar-del-olmo        40.3364465  -3.2355624        Villar del Olmo
# villarejo-de-salvanes  40.1683582  -3.2738764  Villarejo de Salvanés
# villaviciosa-de-odon   40.3573787  -3.9002334   Villaviciosa de Odón
# villavieja-del-lozoya  41.0063622  -3.6716291  Villavieja del Lozoya
# zarzalejo              40.5483016  -4.1815899              Zarzalejo
#
# [176 rows x 3 columns]

# %%
df_municipios.reset_index(inplace=True)

# %%
df_municipios.columns
# Out:
# Index(['index', 0, 1, 2], dtype='object')

# %%
df_municipios.shape
# Out:
# (176, 4)

# %%
df_municipios['index'].unique
# Out:
# <bound method Series.unique of 0                 acebeda-la
# 1                    ajalvir
# 2          alameda-del-valle
# 3                   alamo-el
# 4          alcala-de-henares
#                ...
# 171          villar-del-olmo
# 172    villarejo-de-salvanes
# 173     villaviciosa-de-odon
# 174    villavieja-del-lozoya
# 175                zarzalejo
# Name: index, Length: 176, dtype: object>

# %%
df_municipios[1] = df_municipios[1].astype(float)
# Out:
# 0     -3.624399
# 1     -3.480782
# 2     -3.843822
# 3     -3.990589
# 4     -3.364497
#          ...
# 171   -3.235562
# 172   -3.273876
# 173   -3.900233
# 174   -3.671629
# 175   -4.181590
# Name: 1, Length: 176, dtype: float64

# %%
dfdf_municipios[0].astype(float)
# Out:
# 0      41.086958
# 1      40.534230
# 2      40.917718
# 3      40.230730
# 4      40.481840
#          ...
# 171    40.336447
# 172    40.168358
# 173    40.357379
# 174    41.006362
# 175    40.548302
# Name: 0, Length: 176, dtype: float64

# %%
df_municipios.dtypes
# Out:
# index    object
# 0        object
# 1        object
# 2        object
# dtype: object

# %%
lista_mun_ = []
for fila in df_municipios.values:
    lista_mun_.append(tuple(fila))

# %%
lista_mun_
# Out:
# [('acebeda-la', '41.0869583', '-3.624399', 'La Acebeda'),
#  ('ajalvir', '40.5342302', '-3.4807818', 'Ajalvir'),
#  ('alameda-del-valle', '40.9177178', '-3.8438216', 'Alameda del Valle'),
#  ('alamo-el', '40.2307296', '-3.9905893', 'El Álamo'),
#  ('alcala-de-henares', '40.4818396', '-3.3644973', 'Alcalá de Henares'),
#  ('alcobendas', '40.5400082', '-3.6358494', 'Alcobendas'),
#  ('alcorcon', '40.3492998', '-3.8284295', 'Alcorcón'),
#  ('aldea-del-fresno', '40.3215212', '-4.19936', 'Aldea del Fresno'),
#  ('algete', '40.5961652', '-3.4974246', 'Algete'),
#  ('alpedrete', '40.6599005', '-4.0251223', 'Alpedrete'),
#  ('ambite', '40.3289723', '-3.1812115', 'Ambite'),
#  ('anchuelo', '40.4653862', '-3.2689196', 'Anchuelo'),
#  ('aranjuez', '40.03221', '-3.6039604', 'Aranjuez'),
#  ('arganda-del-rey', '40.3007708', '-3.4380688', 'Arganda del Rey'),
#  ('arroyomolinos', '39.1855991', '-6.1630632', 'Arroyomolinos'),
#  ('atazar-el', '40.9343489', '-3.4710919', 'El Atazar'),
#  ('batres', '40.2091393', '-3.9215947', 'Batres'),
#  ('becerril-de-la-sierra',
#   '40.7163374',
#   '-3.9890681',
#   'Becerril de la Sierra'),
#  ('belmonte-de-tajo', '40.1336305', '-3.3398654', 'Belmonte de Tajo'),
#  ('berrueco-el', '40.8889705', '-3.5614344', 'El Berrueco'),
#  ('berzosa-del-lozoya', '40.9757802', '-3.5236736', 'Berzosa del Lozoya'),
#  ('boadilla-del-monte', '40.4053485', '-3.8764663', 'Boadilla del Monte'),
#  ('boalo-el', '40.7173359', '-3.9202198', 'El Boalo'),
#  ('braojos', '41.0400124', '-3.6425888', 'Braojos'),
#  ('brea-de-tajo', '40.2302134', '-3.1092543', 'Brea de Tajo'),
#  ('brunete', '40.4050499', '-3.9979912', 'Brunete'),
#  ('buitrago-del-lozoya', '40.9953477', '-3.6350501', 'Buitrago del Lozoya'),
#  ('bustarviejo', '40.8587766', '-3.7097632', 'Bustarviejo'),
#  ('cabanillas-de-la-sierra',
#   '40.8216089',
#   '-3.6259742',
#   'Cabanillas de la Sierra'),
#  ('cadalso-de-los-vidrios',
#   '40.3014283',
#   '-4.4408876',
#   'Cadalso de los Vidrios'),
#  ('camarma-de-esteruelas',
#   '40.5490368',
#   '-3.3786211',
#   'Camarma de Esteruelas'),
#  ('campo-real', '40.3381881', '-3.3813911', 'Campo Real'),
#  ('canencia', '40.9095894', '-3.7375609', 'Canencia'),
#  ('carabana', '40.256626', '-3.2347206', 'Carabaña'),
#  ('casarrubuelos', '40.1707803', '-3.8308526', 'Casarrubuelos'),
#  ('cenicientos', '40.2631894', '-4.4669801', 'Cenicientos'),
#  ('cercedilla', '40.7412931', '-4.0558002', 'Cercedilla'),
#  ('cervera-de-buitrago', '40.9211319', '-3.5293404', 'Cervera de Buitrago'),
#  ('chapineria', '40.379164', '-4.2097254', 'Chapinería'),
#  ('chinchon', '40.1408293', '-3.4231474', 'Chinchón'),
#  ('ciempozuelos', '40.1580087', '-3.6205514', 'Ciempozuelos'),
#  ('cobena', '40.5676083', '-3.5048565', 'Cobeña'),
#  ('collado-mediano', '40.6943707', '-4.0247212', 'Collado Mediano'),
#  ('collado-villalba', '40.6431496', '-3.9930128', 'Collado Villalba'),
#  ('colmenar-del-arroyo', '40.4179997', '-4.1972768', 'Colmenar del Arroyo'),
#  ('colmenar-de-oreja', '40.1074198', '-3.3871634', 'Colmenar de Oreja'),
#  ('colmenarejo', '40.5607257', '-4.0165248', 'Colmenarejo'),
#  ('colmenar-viejo', '40.6587726', '-3.7659722', 'Colmenar Viejo'),
#  ('corpa', '40.4235374', '-3.2652482', 'Corpa'),
#  ('coslada', '40.423802', '-3.5552882', 'Coslada'),
#  ('cubas-de-la-sagra', '40.1908352', '-3.8378366', 'Cubas de la Sagra'),
#  ('daganzo-de-arriba', '40.5451953', '-3.45785', 'Daganzo de Arriba'),
#  ('escorial-el',
#   '40.5890661',
#   '-4.147394873409854',
#   'Real Monasterio de San Lorenzo de El Escorial'),
#  ('estremera', '40.1847306', '-3.1062403', 'Estremera'),
#  ('fresnedillas-de-la-oliva',
#   '40.486444',
#   '-4.1723486',
#   'Fresnedillas de la Oliva'),
#  ('fresno-de-torote', '40.5922684', '-3.4119681', 'Fresno de Torote'),
#  ('fuenlabrada', '40.282476', '-3.7923422', 'Fuenlabrada'),
#  ('fuente-el-saz-de-jarama',
#   '40.6312151',
#   '-3.5125918',
#   'Fuente el Saz de Jarama'),
#  ('fuentiduena-de-tajo', '40.1185446', '-3.160254', 'Fuentidueña de Tajo'),
#  ('galapagar', '40.5774992', '-4.0037748', 'Galapagar'),
#  ('garganta-de-los-montes',
#   '40.9216084',
#   '-3.6866546',
#   'Garganta de los Montes'),
#  ('gargantilla-del-lozoya-y-pinilla-de-buitrago',
#   '40.96551504999999',
#   '-3.7077907634147276',
#   'Gargantilla del Lozoya y Pinilla de Buitrago'),
#  ('gascones', '41.0185654', '-3.641499', 'Gascones'),
#  ('getafe', '40.3070639', '-3.7331808', 'Getafe'),
#  ('grinon', '40.2136607', '-3.8581479', 'Griñón'),
#  ('guadalix-de-la-sierra',
#   '40.7822384',
#   '-3.7007794',
#   'Guadalix de la Sierra'),
#  ('guadarrama', '40.6734454', '-4.0893911', 'Guadarrama'),
#  ('hiruela-la', '41.0779223', '-3.4552928', 'La Hiruela'),
#  ('horcajo-de-la-sierra-aoslos',
#   '41.078683',
#   '-3.583901523172418',
#   'Horcajo de la Sierra-Aoslos'),
#  ('horcajuelo-de-la-sierra',
#   '41.0601151',
#   '-3.5457391',
#   'Horcajuelo de la Sierra'),
#  ('hoyo-de-manzanares', '40.6227334', '-3.9072054', 'Hoyo de Manzanares'),
#  ('humanes-de-madrid', '40.2508847', '-3.8270997', 'Humanes de Madrid'),
#  ('loeches', '40.3837901', '-3.4092281', 'Loeches'),
#  ('lozoya', '40.9513281', '-3.7917078', 'Lozoya'),
#  ('lozoyuela-navas-sieteiglesias',
#   '40.9263383',
#   '-3.6176377',
#   'Lozoyuela-Navas-Sieteiglesias'),
#  ('madarcos', '41.0477311', '-3.5821549', 'Madarcos'),
#  ('madrid', '40.4167047', '-3.7035825', 'Madrid'),
#  ('majadahonda', '40.473055', '-3.8724138', 'Majadahonda'),
#  ('manzanares-el-real', '40.7267632', '-3.864981', 'Manzanares el Real'),
#  ('meco', '40.553746', '-3.3281561', 'Meco'),
#  ('mejorada-del-campo', '40.3971785', '-3.4896068', 'Mejorada del Campo'),
#  ('miraflores-de-la-sierra',
#   '40.8137532',
#   '-3.7667236',
#   'Miraflores de la Sierra'),
#  ('molar-el', '40.7347865', '-3.584376', 'El Molar'),
#  ('montejo-de-la-sierra', '41.0593529', '-3.530299', 'Montejo de la Sierra'),
#  ('moraleja-de-enmedio', '40.2615532', '-3.8612117', 'Moraleja de Enmedio'),
#  ('moralzarzal', '40.6791436', '-3.9720985', 'Moralzarzal'),
#  ('morata-de-tajuna', '40.2294297', '-3.4366925', 'Morata de Tajuña'),
#  ('mostoles', '40.3238525', '-3.8649214', 'Móstoles'),
#  ('navacerrada', '40.7287926', '-4.0151676', 'Navacerrada'),
#  ('navalafuente', '40.8232617', '-3.6747292', 'Navalafuente'),
#  ('navalagamella', '40.4690591', '-4.1227079', 'Navalagamella'),
#  ('navalcarnero', '40.2877169', '-4.014299', 'Navalcarnero'),
#  ('navarredonda-y-san-mames',
#   '41.00736645',
#   '-3.7315049706950285',
#   'Navarredonda y San Mamés'),
#  ('navas-del-rey', '40.3863666', '-4.2508402', 'Navas del Rey'),
#  ('nuevo-baztan', '40.3659255', '-3.2443102', 'Nuevo Baztán'),
#  ('olmeda-de-las-fuentes',
#   '40.3695225',
#   '-3.2213199',
#   'Olmeda de las Fuentes'),
#  ('orusco-de-tajuna', '40.2853409', '-3.2096521', 'Orusco de Tajuña'),
#  ('paracuellos-de-jarama',
#   '40.5048527',
#   '-3.5317621',
#   'Paracuellos de Jarama'),
#  ('parla', '40.2373952', '-3.7718902', 'Parla'),
#  ('patones', '40.8548194', '-3.483954', 'Patones'),
#  ('pedrezuela', '40.7451088', '-3.6030185', 'Pedrezuela'),
#  ('pelayos-de-la-presa', '40.3605272', '-4.3334254', 'Pelayos de la Presa'),
#  ('perales-de-tajuna', '40.2325718', '-3.3517265', 'Perales de Tajuña'),
#  ('pezuela-de-las-torres',
#   '40.4186483',
#   '-3.1778029',
#   'Pezuela de las Torres'),
#  ('pinilla-del-valle', '40.9261949', '-3.8184676', 'Pinilla del Valle'),
#  ('pinto', '40.240985', '-3.7005072', 'Pinto'),
#  ('pinuecar-gandullas',
#   '41.03554635',
#   '-3.599475586218161',
#   'Piñuécar-Gandullas'),
#  ('pozuelo-de-alarcon', '40.4346528', '-3.814834', 'Pozuelo de Alarcón'),
#  ('pozuelo-del-rey', '40.3664055', '-3.3200082', 'Pozuelo del Rey'),
#  ('pradena-del-rincon', '41.0443369', '-3.5402284', 'Prádena del Rincón'),
#  ('puebla-de-la-sierra', '41.0121247', '-3.4444367', 'Puebla de la Sierra'),
#  ('puentes-viejas-manjiron', '40.9654041', '-3.5828764', 'Manjirón'),
#  ('quijorna', '40.4290833', '-4.0565378', 'Quijorna'),
#  ('rascafria', '40.9038871', '-3.8802853', 'Rascafría'),
#  ('reduena', '40.8158054', '-3.6039309', 'Redueña'),
#  ('ribatejada', '40.6664949', '-3.3919178', 'Ribatejada'),
#  ('rivas-vaciamadrid', '40.3536054', '-3.5310879', 'Rivas-Vaciamadrid'),
#  ('robledillo-de-la-jara',
#   '40.9529148',
#   '-3.5250504',
#   'Robledillo de la Jara'),
#  ('robledo-de-chavela', '40.5009201', '-4.2380999', 'Robledo de Chavela'),
#  ('robregordo', '41.1064517', '-3.5937466', 'Robregordo'),
#  ('rozas-de-madrid-las', '40.4933095', '-3.8758396', 'Las Rozas de Madrid'),
#  ('rozas-de-puerto-real', '40.3098351', '-4.4912111', 'Rozas de Puerto Real'),
#  ('san-agustin-del-guadalix',
#   '40.679051',
#   '-3.6166004',
#   'San Agustín del Guadalix'),
#  ('san-fernando-de-henares',
#   '40.4248548',
#   '-3.5350369',
#   'San Fernando de Henares'),
#  ('san-lorenzo-de-el-escorial',
#   '40.5926673',
#   '-4.1471642',
#   'San Lorenzo de El Escorial'),
#  ('san-martin-de-la-vega',
#   '40.2110462',
#   '-3.5771806',
#   'San Martín de la Vega'),
#  ('san-martin-de-valdeiglesias',
#   '40.3625',
#   '-4.3986503',
#   'San Martín de Valdeiglesias'),
#  ('san-sebastian-de-los-reyes',
#   '40.5473698',
#   '-3.6260586',
#   'San Sebastián de los Reyes'),
#  ('santa-maria-de-la-alameda',
#   '40.5958248',
#   '-4.2579208',
#   'Santa María de la Alameda'),
#  ('santorcaz', '40.4715789', '-3.2335594', 'Santorcaz'),
#  ('santos-de-la-humosa-los',
#   '40.5012957',
#   '-3.2566803',
#   'Los Santos de la Humosa'),
#  ('serna-del-monte-la', '41.0305793', '-3.6252636', 'La Serna del Monte'),
#  ('serranillos-del-valle',
#   '40.2044509',
#   '-3.8851988',
#   'Serranillos del Valle'),
#  ('sevilla-la-nueva', '40.3475422', '-4.0275268', 'Sevilla la Nueva'),
#  ('somosierra', '41.133207', '-3.581478', 'Somosierra'),
#  ('soto-del-real', '40.7534432', '-3.7866573', 'Soto del Real'),
#  ('talamanca-de-jarama', '40.7454625', '-3.5127366', 'Talamanca de Jarama'),
#  ('tielmes', '40.2465011', '-3.3136206', 'Tielmes'),
#  ('titulcia', '40.1379148', '-3.5709978', 'Titulcia'),
#  ('torrejon-de-ardoz', '40.4587767', '-3.4793343', 'Torrejón de Ardoz'),
#  ('torrejon-de-la-calzada',
#   '40.2006804',
#   '-3.7993298',
#   'Torrejón de la Calzada'),
#  ('torrejon-de-velasco', '40.1869283', '-3.7769069', 'Torrejón de Velasco'),
#  ('torrelaguna', '40.8277273', '-3.538293', 'Torrelaguna'),
#  ('torrelodones', '40.5762809', '-3.928603', 'Torrelodones'),
#  ('torremocha-de-jarama', '40.8358114', '-3.4966866', 'Torremocha de Jarama'),
#  ('torres-de-la-alameda', '40.4021516', '-3.360625', 'Torres de la Alameda'),
#  ('tres-cantos', '40.6065826', '-3.7065333', 'Tres Cantos'),
#  ('valdaracete', '40.2107697', '-3.1954758', 'Valdaracete'),
#  ('valdeavero', '40.6309749', '-3.3329368', 'Valdeavero'),
#  ('valdelaguna', '40.1605777', '-3.367827', 'Valdelaguna'),
#  ('valdemanco', '40.8736636', '-3.6636949', 'Valdemanco'),
#  ('valdemaqueda', '40.5110297', '-4.2977731', 'Valdemaqueda'),
#  ('valdemorillo', '40.5016772', '-4.0688878', 'Valdemorillo'),
#  ('valdemoro', '40.1888604', '-3.67143', 'Valdemoro'),
#  ('valdeolmos-alalpardo', '40.6385429', '-3.4532436', 'Valdeolmos-Alalpardo'),
#  ('valdepielagos', '40.7610144', '-3.4656251', 'Valdepiélagos'),
#  ('valdetorres-de-jarama',
#   '40.6956481',
#   '-3.5146559',
#   'Valdetorres de Jarama'),
#  ('valdilecha', '40.2926854', '-3.3002096', 'Valdilecha'),
#  ('valverde-de-alcala', '40.4180359', '-3.2996775', 'Valverde de Alcalá'),
#  ('velilla-de-san-antonio',
#   '40.367166',
#   '-3.4874435',
#   'Velilla de San Antonio'),
#  ('vellon-el', '40.7677965', '-3.5820099', 'El Vellón'),
#  ('venturada', '40.7985257', '-3.6207369', 'Venturada'),
#  ('villaconejos', '40.1040079', '-3.4850284', 'Villaconejos'),
#  ('villa-del-prado', '40.2764752', '-4.3048032', 'Villa del Prado'),
#  ('villalbilla', '40.4323665', '-3.2987815', 'Villalbilla'),
#  ('villamanrique-de-tajo', '40.0686973', '-3.240078', 'Villamanrique de Tajo'),
#  ('villamanta', '40.2990939', '-4.1090399', 'Villamanta'),
#  ('villamantilla', '40.3421033', '-4.1300303', 'Villamantilla'),
#  ('villanueva-de-la-canada',
#   '40.4472106',
#   '-4.002795',
#   'Villanueva de la Cañada'),
#  ('villanueva-del-pardillo',
#   '40.4949232',
#   '-3.9600065',
#   'Villanueva del Pardillo'),
#  ('villanueva-de-perales',
#   '40.3466066',
#   '-4.1012616',
#   'Villanueva de Perales'),
#  ('villar-del-olmo', '40.3364465', '-3.2355624', 'Villar del Olmo'),
#  ('villarejo-de-salvanes',
#   '40.1683582',
#   '-3.2738764',
#   'Villarejo de Salvanés'),
#  ('villaviciosa-de-odon', '40.3573787', '-3.9002334', 'Villaviciosa de Odón'),
#  ('villavieja-del-lozoya',
#   '41.0063622',
#   '-3.6716291',
#   'Villavieja del Lozoya'),
#  ('zarzalejo', '40.5483016', '-4.1815899', 'Zarzalejo')]

# %%
df_api.columns
# Out:
# Index(['municipio', 'category', 'fsq_id', 'closed_bucket', 'distance', 'link',
#        'name', 'address', 'latitude', 'longitude'],
#       dtype='object')

# %%
df_api.shape
# Out:
# (907, 10)

# %%
df_api.nunique()
# Out:
# municipio         96
# category          10
# fsq_id           822
# closed_bucket      3
# distance         724
# link             822
# name             764
# address          491
# latitude         811
# longitude        812
# dtype: int64

# %%
lista_apis = []
for fila in df_api.values:
        lista_apis.append(tuple(fila))

lista_apis
# Out:
# [('ajalvir',
#   'Park',
#   '4d3c6c5b84d46ea87dddfd5c',
#   'LikelyOpen',
#   563.0,
#   '/v3/places/4d3c6c5b84d46ea87dddfd5c',
#   'Diverjungla',
#   'Calle Segovia, 20 (Pol. Ind. Donada), 28864 Ajalvir Comunidad de Madrid',
#   40.529921,
#   -3.484341),
#  ('ajalvir',
#   'Park',
#   '4f54f7bfe4b036244d02685b',
#   'VeryLikelyOpen',
#   1724.0,
#   '/v3/places/4f54f7bfe4b036244d02685b',
#   'Parque Infantil',
#   nan,
#   40.543867,
#   -3.464773),
#  ('ajalvir',
#   'Park',
#   '7d4ef99ca2dd4789f032a90c',
#   'LikelyOpen',
#   333.0,
#   '/v3/places/7d4ef99ca2dd4789f032a90c',
#   'Chiquitin',
#   'Ajalvir Madrid',
#   40.531662,
#   -3.482835),
#  ('alamo-el',
#   'Park',
#   '53de1144498e8fd8d8cb3537',
#   'LikelyOpen',
#   118.0,
#   '/v3/places/53de1144498e8fd8d8cb3537',
#   'Isla Perejil',
#   '28607 El Alamo Comunidad de Madrid',
#   40.230993,
#   -3.991942),
#  ('alamo-el',
#   'Park',
#   '51a8f451498ecb8334de37df',
#   'LikelyOpen',
#   582.0,
#   '/v3/places/51a8f451498ecb8334de37df',
#   'Parque de Madera',
#   nan,
#   40.234636,
#   -3.995166),
#  ('alcala-de-henares',
#   'Park',
#   '4d9dd4135c33a35de83d0aa1',
#   'VeryLikelyOpen',
#   593.0,
#   '/v3/places/4d9dd4135c33a35de83d0aa1',
#   "Parque O'Donnell",
#   'Calle de Luis de Astrana Marín, 8, 28807 Alcalá de Henares Comunidad de Madrid',
#   40.485077,
#   -3.370226),
#  ('alcala-de-henares',
#   'Park',
#   '4e8cb283f790e886adb6b2d1',
#   'VeryLikelyOpen',
#   326.0,
#   '/v3/places/4e8cb283f790e886adb6b2d1',
#   'Parque del Louisi',
#   'Alcalá de Henares Comunidad de Madrid',
#   40.478976,
#   -3.363647),
#  ('alcala-de-henares',
#   'Park',
#   '6346c5fc0adbe04470eb1b9e',
#   'VeryLikelyOpen',
#   392.0,
#   '/v3/places/6346c5fc0adbe04470eb1b9e',
#   'Parque Infantil',
#   '28801 Alcalá de Henares Comunidad de Madrid',
#   40.479732,
#   -3.368221),
#  ('alcala-de-henares',
#   'Park',
#   '4e73992152b145ffbfa4b2d7',
#   'LikelyOpen',
#   515.0,
#   '/v3/places/4e73992152b145ffbfa4b2d7',
#   'Parque Salvador de Madariaga',
#   'Alcalá de Henares Comunidad de Madrid',
#   40.483588,
#   -3.35885),
#  ('alcala-de-henares',
#   'Park',
#   '4cdd7134d5495481a27047b2',
#   'LikelyOpen',
#   518.0,
#   '/v3/places/4cdd7134d5495481a27047b2',
#   'Parque de Sementales',
#   'Ronda Fiscal, 28804 Alcalá de Henares Comunidad de Madrid',
#   40.477219,
#   -3.363631),
#  ('alcala-de-henares',
#   'Park',
#   '51c5d2c7498e7b1ee63cbaed',
#   'VeryLikelyOpen',
#   1531.0,
#   '/v3/places/51c5d2c7498e7b1ee63cbaed',
#   'Parque del Camarmilla',
#   '28806 Alcalá de Henares Comunidad de Madrid',
#   40.489338,
#   -3.379427),
#  ('alcala-de-henares',
#   'Park',
#   '4e0775e51838eb15af01c1cc',
#   'VeryLikelyOpen',
#   600.0,
#   '/v3/places/4e0775e51838eb15af01c1cc',
#   'Parque Isla del Colegio',
#   'Alcalá de Henares Comunidad de Madrid',
#   40.47753,
#   -3.36021),
#  ('alcala-de-henares',
#   'Park',
#   '314a53383ee34eeb3de00fab',
#   'LikelyOpen',
#   711.0,
#   '/v3/places/314a53383ee34eeb3de00fab',
#   'Ermita de San Isidro (Alcalá de Henares)',
#   '28805 Alcalá de Henares Comunidad de Madrid',
#   40.488094,
#   -3.360983),
#  ('alcala-de-henares',
#   'Park',
#   '4d2da1b012d16a31ed5b2c22',
#   'LikelyOpen',
#   726.0,
#   '/v3/places/4d2da1b012d16a31ed5b2c22',
#   'Parque San Isidro',
#   '28800 Alcalá de Henares Comunidad de Madrid',
#   40.487883,
#   -3.361226),
#  ('alcala-de-henares',
#   'Park',
#   '51122b89e4b02280b86690f4',
#   'LikelyOpen',
#   768.0,
#   '/v3/places/51122b89e4b02280b86690f4',
#   'Parque el Silo',
#   nan,
#   40.48726,
#   -3.370137),
#  ('alcala-de-henares',
#   'Park',
#   '4cdbaabc5aeda1cd1652be11',
#   'LikelyOpen',
#   792.0,
#   '/v3/places/4cdbaabc5aeda1cd1652be11',
#   'Parque de Sementales',
#   'Madrid',
#   40.474705,
#   -3.364397),
#  ('alcala-de-henares',
#   'Park',
#   '4ec542c90aaf9233edc1253d',
#   'VeryLikelyOpen',
#   873.0,
#   '/v3/places/4ec542c90aaf9233edc1253d',
#   'Parque de los Tubos',
#   'Alcalá de Henares Comunidad de Madrid',
#   40.489014,
#   -3.360285),
#  ('alcala-de-henares',
#   'Park',
#   '4f1ddf34e4b0c7ea6a7ceebb',
#   'LikelyOpen',
#   956.0,
#   '/v3/places/4f1ddf34e4b0c7ea6a7ceebb',
#   'Parque del Medio',
#   '28803 Alcalá de Henares Comunidad de Madrid',
#   40.473246,
#   -3.365172),
#  ('alcala-de-henares',
#   'Park',
#   '4fe11f32e4b070217abd91a8',
#   'LikelyOpen',
#   967.0,
#   '/v3/places/4fe11f32e4b070217abd91a8',
#   'Parque de la Hera',
#   nan,
#   40.473476,
#   -3.367675),
#  ('alcala-de-henares',
#   'Park',
#   '4e77051dd4c093447292be2a',
#   'LikelyOpen',
#   998.0,
#   '/v3/places/4e77051dd4c093447292be2a',
#   'Plaza de la Villa de Talence',
#   'C/ Pablo De Olavide, 28804 Alcalá de Henares Comunidad de Madrid',
#   40.485978,
#   -3.354006),
#  ('alcala-de-henares',
#   'Park',
#   '50e5b9dae4b03cb7f42b35e3',
#   'VeryLikelyOpen',
#   1008.0,
#   '/v3/places/50e5b9dae4b03cb7f42b35e3',
#   'Paseo de los Pinos',
#   'Alcalá de Henares Comunidad de Madrid',
#   40.487566,
#   -3.373756),
#  ('alcala-de-henares',
#   'Park',
#   '4f1b3b8be4b05c50e26be096',
#   'LikelyOpen',
#   1048.0,
#   '/v3/places/4f1b3b8be4b05c50e26be096',
#   'Parque Tierno Galvan',
#   'Alcalá de Henares Comunidad de Madrid',
#   40.473131,
#   -3.369276),
#  ('alcala-de-henares',
#   'Park',
#   '50559496e4b0c21074e5a591',
#   'LikelyOpen',
#   1166.0,
#   '/v3/places/50559496e4b0c21074e5a591',
#   'Parque junto a IES Antonio Machado',
#   'C. Villalbilla, 28806 Alcalá de Henares Comunidad de Madrid',
#   40.491908,
#   -3.368385),
#  ('alcala-de-henares',
#   'Park',
#   '4f5a352ae4b0db6b5b6b6e6c',
#   'Unsure',
#   1214.0,
#   '/v3/places/4f5a352ae4b0db6b5b6b6e6c',
#   'La Cruz',
#   'Valencia',
#   40.491891,
#   -3.370152),
#  ('alcala-de-henares',
#   'Park',
#   '4fd9067ce4b01007e991526f',
#   'Unsure',
#   1244.0,
#   '/v3/places/4fd9067ce4b01007e991526f',
#   'Las Boyeras',
#   'Alcalá de Henares Comunidad de Madrid',
#   40.471327,
#   -3.369585),
#  ('alcala-de-henares',
#   'Park',
#   '4d4ea33923a76dcb8bba61dc',
#   'VeryLikelyOpen',
#   1272.0,
#   '/v3/places/4d4ea33923a76dcb8bba61dc',
#   'Area de Juegos Complutum',
#   'Alcalá de Henares Comunidad de Madrid',
#   40.493124,
#   -3.361898),
#  ('alcala-de-henares',
#   'Park',
#   '4bbe466a4e9cd13a4bded92c',
#   'LikelyOpen',
#   1275.0,
#   '/v3/places/4bbe466a4e9cd13a4bded92c',
#   'Parque los Gatos',
#   'C/ Alicante, 28804 Alcalá de Henares Comunidad de Madrid',
#   40.485633,
#   -3.350252),
#  ('alcala-de-henares',
#   'Park',
#   '4e444343d22de4060ef3a8a3',
#   'LikelyOpen',
#   1316.0,
#   '/v3/places/4e444343d22de4060ef3a8a3',
#   'Parque de los Nogales',
#   'Nogales Comunidad de Madrid',
#   40.492901,
#   -3.358933),
#  ('alcala-de-henares',
#   'Park',
#   '4fcd0a9ae4b02808058e999f',
#   'LikelyOpen',
#   1331.0,
#   '/v3/places/4fcd0a9ae4b02808058e999f',
#   'Plaza del Barro',
#   'Barro',
#   40.474195,
#   -3.376624),
#  ('alcala-de-henares',
#   'Park',
#   '507a82fce4b0801689445c90',
#   'LikelyOpen',
#   1389.0,
#   '/v3/places/507a82fce4b0801689445c90',
#   'Parque junto a CEIP Antonio de Nebrija',
#   'C/ San Ignacio de Loyola, 28806 Alcalá de Henares Comunidad de Madrid',
#   40.492208,
#   -3.373689),
#  ('alcala-de-henares',
#   'Park',
#   '561a9bd8498ea95ebfd28b1c',
#   'VeryLikelyOpen',
#   1486.0,
#   '/v3/places/561a9bd8498ea95ebfd28b1c',
#   'Parque de las farolas',
#   nan,
#   40.488078,
#   -3.380041),
#  ('alcala-de-henares',
#   'Park',
#   '4d9b51da5e52224b967640e3',
#   'LikelyOpen',
#   1535.0,
#   '/v3/places/4d9b51da5e52224b967640e3',
#   'Parque Miguel de Unamuno',
#   'Avenida de Miguel de Unamuno, 81, 28805 Alcalá de Henares Comunidad de Madrid',
#   40.495439,
#   -3.361294),
#  ('alcala-de-henares',
#   'Park',
#   '4e80c4ef6c2589140fc57039',
#   'LikelyOpen',
#   1545.0,
#   '/v3/places/4e80c4ef6c2589140fc57039',
#   'Arboreto Reyes Católicos',
#   'Alcalá de Henares Comunidad de Madrid',
#   40.473953,
#   -3.379558),
#  ('alcala-de-henares',
#   'Park',
#   '4bc6261bdb8fa59352d99b37',
#   'Unsure',
#   1567.0,
#   '/v3/places/4bc6261bdb8fa59352d99b37',
#   'Parque Islas Filipinas',
#   'Calle de Santander (Avenida Lope de Figueroa), 28804 Alcalá de Henares Comunidad de Madrid',
#   40.488015,
#   -3.347935),
#  ('alcala-de-henares',
#   'Park',
#   '4ddd21c0ae60d6fc159c3ec4',
#   'LikelyOpen',
#   1642.0,
#   '/v3/places/4ddd21c0ae60d6fc159c3ec4',
#   'El Jardin del Parnaso',
#   'C/ Bertolt Brecht, 28806 Alcalá de Henares Comunidad de Madrid',
#   40.496231,
#   -3.368913),
#  ('alcala-de-henares',
#   'Park',
#   '4e99c5f7e5fa3f633ce6b9c4',
#   'LikelyOpen',
#   1803.0,
#   '/v3/places/4e99c5f7e5fa3f633ce6b9c4',
#   'Parque Infantil',
#   nan,
#   40.495352,
#   -3.376328),
#  ('alcala-de-henares',
#   'Park',
#   '5043c451e4b053a532950fea',
#   'LikelyOpen',
#   1810.0,
#   '/v3/places/5043c451e4b053a532950fea',
#   'Parque junto a Parking',
#   'C/ Luis Rosales, 28006 Alcalá de Henares Comunidad de Madrid',
#   40.495488,
#   -3.376194),
#  ('alcala-de-henares',
#   'Park',
#   'f5473808045e4d28c7008839',
#   'LikelyOpen',
#   1817.0,
#   '/v3/places/f5473808045e4d28c7008839',
#   'El Mundo de Pik',
#   'Carretera de Daganzo, Km 2, 28806 Alcalá de Henares Comunidad de Madrid',
#   40.492975,
#   -3.380249),
#  ('alcala-de-henares',
#   'Park',
#   '51eac228498ef79bc92359c5',
#   'LikelyOpen',
#   1828.0,
#   '/v3/places/51eac228498ef79bc92359c5',
#   'Parque junto a IES Doctor Marañón',
#   'Marañón',
#   40.495824,
#   -3.375898),
#  ('alcala-de-henares',
#   'Park',
#   '4ec8e71830f8b09c0da84061',
#   'VeryLikelyOpen',
#   1867.0,
#   '/v3/places/4ec8e71830f8b09c0da84061',
#   'Parque de los Cerros',
#   nan,
#   40.466554,
#   -3.355329),
#  ('alcala-de-henares',
#   'Park',
#   '4f8f3333e4b0dcea364b18a5',
#   'LikelyOpen',
#   1880.0,
#   '/v3/places/4f8f3333e4b0dcea364b18a5',
#   'Parque Andalucia',
#   nan,
#   40.487195,
#   -3.343389),
#  ('alcala-de-henares',
#   'Park',
#   'bd9c47d0e3414ac8a24a9d8a',
#   'Unsure',
#   897.0,
#   '/v3/places/bd9c47d0e3414ac8a24a9d8a',
#   'Plaza de la Juventud',
#   'Alcalá de Henares Madrid',
#   40.481597,
#   -3.353885),
#  ('alcala-de-henares',
#   'Monument',
#   '5cf28719471d6e002cea086c',
#   'VeryLikelyOpen',
#   66.0,
#   '/v3/places/5cf28719471d6e002cea086c',
#   'Monumento de Cervantes',
#   '28801 Alcalá de Henares Comunidad de Madrid',
#   40.482409,
#   -3.364249),
#  ('alcala-de-henares',
#   'Monument',
#   '4ea8583dbe7b572daaf511f6',
#   'LikelyOpen',
#   99.0,
#   '/v3/places/4ea8583dbe7b572daaf511f6',
#   'Capilla del Oidor',
#   'Plaza Cervantes, 0, 28801 Alcalá de Henares Comunidad de Madrid',
#   40.481471,
#   -3.363425),
#  ('alcala-de-henares',
#   'Monument',
#   '5241fe7e498e0391853428d9',
#   'VeryLikelyOpen',
#   120.0,
#   '/v3/places/5241fe7e498e0391853428d9',
#   'Capilla de San Ildefonso',
#   'Plaza de San Diego (Pedro Gumiel), 28801 Alcalá de Henares Comunidad de Madrid',
#   40.48235,
#   -3.363433),
#  ('alcala-de-henares',
#   'Monument',
#   'f88eb960d3a04c122ae37cef',
#   'LikelyOpen',
#   376.0,
#   '/v3/places/f88eb960d3a04c122ae37cef',
#   'Oratorio de San Felipe Neri',
#   'Calle San Felipe Neri, 4, 28801 Alcalá de Henares Comunidad de Madrid',
#   40.481623,
#   -3.368945),
#  ('alcala-de-henares',
#   'Monument',
#   '3a56ae6ddd6d49ffa16b0649',
#   'VeryLikelyOpen',
#   398.0,
#   '/v3/places/3a56ae6ddd6d49ffa16b0649',
#   'Catedral Magistral de Alcala de Henares',
#   'Plaza de los Santos Niños, s/n, 28801 Alcalá de Henares Comunidad de Madrid',
#   40.480722,
#   -3.369099),
#  ('alcala-de-henares',
#   'Monument',
#   '4f3fcbb5e4b0bc95af8d1489',
#   'VeryLikelyOpen',
#   496.0,
#   '/v3/places/4f3fcbb5e4b0bc95af8d1489',
#   'Estatua Quijote',
#   'Alcalá de Henares Comunidad de Madrid',
#   40.486054,
#   -3.362542),
#  ('alcala-de-henares',
#   'Monument',
#   'd9041734492346311f2c6c13',
#   'LikelyOpen',
#   668.0,
#   '/v3/places/d9041734492346311f2c6c13',
#   'Palacio Laredo',
#   'Paseo de la Estacion, 10, 28807 Alcalá de Henares Comunidad de Madrid',
#   40.487841,
#   -3.363999),
#  ('alcala-de-henares',
#   'Monument',
#   'd52b434e8a2a45967eb0fcab',
#   'LikelyOpen',
#   12.0,
#   '/v3/places/d52b434e8a2a45967eb0fcab',
#   'Casa Consistorial de Alcalá de Henares',
#   'Plaza de Cervantes, 12, 28801 Alcalá de Henares Madrid',
#   40.481808,
#   -3.364352),
#  ('alcala-de-henares',
#   'Monument',
#   'd7f723ab2a8a4076ed4315d6',
#   'LikelyOpen',
#   123.0,
#   '/v3/places/d7f723ab2a8a4076ed4315d6',
#   'Ludo y Sofía',
#   'Calle Santa Úrsula, 7, 28801 Alcalá de Henares Madrid',
#   40.481005,
#   -3.365459),
#  ('alcala-de-henares',
#   'Monument',
#   '16b8df548af04f16506bb2db',
#   'LikelyOpen',
#   264.0,
#   '/v3/places/16b8df548af04f16506bb2db',
#   'Convento de la Imagen',
#   '28801 Alcalá de Henares Madrid',
#   40.482597,
#   -3.367458),
#  ('alcala-de-henares',
#   'Monument',
#   '9d866cc87d374d9f58f4dc33',
#   'LikelyOpen',
#   356.0,
#   '/v3/places/9d866cc87d374d9f58f4dc33',
#   'Convento de San Juan de la Penitencia',
#   'Calle Santiago, N, 3, 28801 Alcalá de Henares Madrid',
#   40.482736,
#   -3.368547),
#  ('alcala-de-henares',
#   'Monument',
#   '5b44203ee5294377d7ee3a9a',
#   'LikelyOpen',
#   372.0,
#   '/v3/places/5b44203ee5294377d7ee3a9a',
#   'Palacio Arzobispal de Alcalá de Henares',
#   'Alcalá de Henares Madrid',
#   40.4824,
#   -3.368843),
#  ('alcala-de-henares',
#   'Monument',
#   'e9142be40e4e452009f0959a',
#   'LikelyOpen',
#   414.0,
#   '/v3/places/e9142be40e4e452009f0959a',
#   'Convento del Corpus Christi',
#   '28801 Alcalá de Henares Madrid',
#   40.482016,
#   -3.359597),
#  ('alcala-de-henares',
#   'Monument',
#   '19b01eccf709404725fd7102',
#   'Unsure',
#   1066.0,
#   '/v3/places/19b01eccf709404725fd7102',
#   'Murrallas de la Ciudad',
#   'Alcalá de Henares Madrid',
#   40.488875,
#   -3.355907),
#  ('alcala-de-henares',
#   'Monument',
#   '02c770b3d0c54cbfc2190079',
#   'Unsure',
#   1548.0,
#   '/v3/places/02c770b3d0c54cbfc2190079',
#   'Centro Comercial Alcalá Atenea',
#   'Alcalá de Henares Madrid',
#   40.468185,
#   -3.368171),
#  ('alcobendas',
#   'Park',
#   '4bf6ab0d004ed13a9bd842a0',
#   'VeryLikelyOpen',
#   739.0,
#   '/v3/places/4bf6ab0d004ed13a9bd842a0',
#   'Parque Temático del Barco Pirata',
#   'Alcobendas Comunidad de Madrid',
#   40.536798,
#   -3.628183),
#  ('alcobendas',
#   'Park',
#   '4bc0a91d4cdfc9b6dc2f9321',
#   'VeryLikelyOpen',
#   555.0,
#   '/v3/places/4bc0a91d4cdfc9b6dc2f9321',
#   'Jardín de la Vega',
#   'Avenida Olímpica Con Una Superficie de 180.000, 28108 Alcobendas Comunidad de Madrid',
#   40.536178,
#   -3.631666),
#  ('alcobendas',
#   'Park',
#   '4bd1e9c4462cb713df2adb07',
#   'LikelyOpen',
#   888.0,
#   '/v3/places/4bd1e9c4462cb713df2adb07',
#   'Parque de Andalucía',
#   '28100 Alcobendas Comunidad de Madrid',
#   40.539522,
#   -3.646352),
#  ('alcobendas',
#   'Park',
#   '4bdbf36663c5c9b6ad0f2a68',
#   'VeryLikelyOpen',
#   1921.0,
#   '/v3/places/4bdbf36663c5c9b6ad0f2a68',
#   'Parque Temático del Hormiguero',
#   'Alcobendas Comunidad de Madrid',
#   40.543703,
#   -3.65808),
#  ('alcobendas',
#   'Park',
#   '4c797b7493ef236a27c8af0f',
#   'LikelyOpen',
#   1747.0,
#   '/v3/places/4c797b7493ef236a27c8af0f',
#   'Parque de la Marina',
#   '28703 San Sebastián de los Reyes Comunidad de Madrid',
#   40.553699,
#   -3.627469),
#  ('alcobendas',
#   'Park',
#   '4d541f65d4a6721ebfe291ac',
#   'LikelyOpen',
#   379.0,
#   '/v3/places/4d541f65d4a6721ebfe291ac',
#   'Parque',
#   'Calle de Ramón Esteban, 30, 28701 Alcobendas Comunidad de Madrid',
#   40.539004,
#   -3.63162),
#  ('alcobendas',
#   'Park',
#   '4db66a4e4b226b343db4408d',
#   'LikelyOpen',
#   112.0,
#   '/v3/places/4db66a4e4b226b343db4408d',
#   'Parque de la Artesanía',
#   'Calle de Ramón Fernández Guisasola, 22, 28100 Alcobendas Comunidad de Madrid',
#   40.540983,
#   -3.636226),
#  ('alcobendas',
#   'Park',
#   '50005379e4b0d0c03f9c1212',
#   'VeryLikelyOpen',
#   397.0,
#   '/v3/places/50005379e4b0d0c03f9c1212',
#   'Parque Victimas del Terrorismo',
#   'Comunidad de Madrid',
#   40.537022,
#   -3.638439),
#  ('alcobendas',
#   'Park',
#   '4fb8c015e4b018d6ec5aa9f3',
#   'LikelyOpen',
#   454.0,
#   '/v3/places/4fb8c015e4b018d6ec5aa9f3',
#   'Parque de Murcia',
#   'Alcobendas Comunidad de Madrid',
#   40.539345,
#   -3.630479),
#  ('alcobendas',
#   'Park',
#   '4f907c3fbe77acb15eed2bd4',
#   'LikelyOpen',
#   497.0,
#   '/v3/places/4f907c3fbe77acb15eed2bd4',
#   'Área Canina Parque Arroyo de la Vega',
#   'Av. de la Ermita, 28100 Alcobendas Comunidad de Madrid',
#   40.535582,
#   -3.634985),
#  ('alcobendas',
#   'Park',
#   '4f96a921e5e8d28602a214f6',
#   'LikelyOpen',
#   541.0,
#   '/v3/places/4f96a921e5e8d28602a214f6',
#   'Área Canina Parque Víctimas del Terrorismo',
#   'c/ Pintor Velázquez, 28100 Alcobendas Comunidad de Madrid',
#   40.53613,
#   -3.639737),
#  ('alcobendas',
#   'Park',
#   '5220f28c11d2303d8df78500',
#   'LikelyOpen',
#   591.0,
#   '/v3/places/5220f28c11d2303d8df78500',
#   'Parque Comunidad de Madrid',
#   'Comunidad de Madrid',
#   40.54536,
#   -3.638054),
#  ('alcobendas',
#   'Park',
#   '4f908136be77acb15eedb0e0',
#   'LikelyOpen',
#   610.0,
#   '/v3/places/4f908136be77acb15eedb0e0',
#   'Área Canina Parque Comunidad de Madrid',
#   'c/ Jarama, 28100 Alcobendas Comunidad de Madrid',
#   40.545246,
#   -3.638026),
#  ('alcobendas',
#   'Park',
#   '4f9144ef121d1e2a7d9039f1',
#   'Unsure',
#   616.0,
#   '/v3/places/4f9144ef121d1e2a7d9039f1',
#   'Parque de Valencia',
#   'Avenida de España, s/n (c/ Bachiller Alonso López), 28100 Alcobendas Comunidad de Madrid',
#   40.544589,
#   -3.632399),
#  ('alcobendas',
#   'Park',
#   '4c6bbde2599fbe9ad644933f',
#   'LikelyOpen',
#   629.0,
#   '/v3/places/4c6bbde2599fbe9ad644933f',
#   'Parque Camilo Cienfuegos',
#   'Jarama, Alcobendas Comunidad de Madrid',
#   40.545458,
#   -3.637783),
#  ('alcobendas',
#   'Park',
#   '4f905487be77b06bd1a34aed',
#   'Unsure',
#   729.0,
#   '/v3/places/4f905487be77b06bd1a34aed',
#   'Área canina Parque Andalucía',
#   'Pintor Murillo, 14, 28100 Alcobendas Comunidad de Madrid',
#   40.539328,
#   -3.644441),
#  ('alcobendas',
#   'Park',
#   '4dbc68981e72b351cab26468',
#   'VeryLikelyOpen',
#   766.0,
#   '/v3/places/4dbc68981e72b351cab26468',
#   'Parque de la universidad',
#   '28100 Alcobendas Comunidad de Madrid',
#   40.542205,
#   -3.644451),
#  ('alcobendas',
#   'Park',
#   '71eaa141ffd24d8a58e47783',
#   'LikelyOpen',
#   789.0,
#   '/v3/places/71eaa141ffd24d8a58e47783',
#   'Colorin',
#   'Sacramento, 3, 28701 San Sebastián de los Reyes Comunidad de Madrid',
#   40.544654,
#   -3.628691),
#  ('alcobendas',
#   'Park',
#   '4f96a2cbe5e8d28602a157a2',
#   'LikelyOpen',
#   965.0,
#   '/v3/places/4f96a2cbe5e8d28602a157a2',
#   'Área Canina Parque de Navarra',
#   'Calle Marqués de la Valdavia, 90, 28100 Alcobendas Comunidad de Madrid',
#   40.545175,
#   -3.645034),
#  ('alcobendas',
#   'Park',
#   '4f907117be77b06bd1a6c0c0',
#   'LikelyOpen',
#   969.0,
#   '/v3/places/4f907117be77b06bd1a6c0c0',
#   'Área Canina Parque Navarra',
#   'Calle Marqués de la Valdavia, 90 (Av. de España), 28100 Alcobendas Comunidad de Madrid',
#   40.5453,
#   -3.644981),
#  ('alcobendas',
#   'Park',
#   '4dbfc8b881545e1cc7d526d0',
#   'LikelyOpen',
#   977.0,
#   '/v3/places/4dbfc8b881545e1cc7d526d0',
#   'Parque navarra',
#   '28100 Alcobendas Comunidad de Madrid',
#   40.545077,
#   -3.645306),
#  ('alcobendas',
#   'Park',
#   '4fad04db6d866e7143cb70fc',
#   'VeryLikelyOpen',
#   997.0,
#   '/v3/places/4fad04db6d866e7143cb70fc',
#   'Recinto Ferial Alcobendas',
#   'Huelva, s/n (Parque de Andalucía), 28100 Alcobendas Comunidad de Madrid',
#   40.541593,
#   -3.64747),
#  ('alcobendas',
#   'Park',
#   '4f96a5e6e5e8d28602a1b3c8',
#   'LikelyOpen',
#   1051.0,
#   '/v3/places/4f96a5e6e5e8d28602a1b3c8',
#   'Área Canina Parque Castilla la Mancha',
#   'c/ Pintor Murillo, 28100 Alcobendas Comunidad de Madrid',
#   40.5418,
#   -3.648073),
#  ('alcobendas',
#   'Park',
#   '51f8018a498eb166c4309500',
#   'LikelyOpen',
#   1169.0,
#   '/v3/places/51f8018a498eb166c4309500',
#   'Parque de las Sombras',
#   'San Sebastián de los Reyes Comunidad de Madrid',
#   40.550475,
#   -3.634356),
#  ('alcobendas',
#   'Park',
#   '4bf907255ec320a179a189d3',
#   'VeryLikelyOpen',
#   1186.0,
#   '/v3/places/4bf907255ec320a179a189d3',
#   'Parque de la Petunia',
#   nan,
#   40.529331,
#   -3.63556),
#  ('alcobendas',
#   'Park',
#   '5124a448e4b07a4d95ecf39b',
#   'LikelyOpen',
#   1225.0,
#   '/v3/places/5124a448e4b07a4d95ecf39b',
#   'Área Canina Parque Temático Hormiguero',
#   'Av. Valdelaparra, 28100 Alcobendas Comunidad de Madrid',
#   40.542647,
#   -3.649938),
#  ('alcobendas',
#   'Park',
#   '4ffef79345b0986b7d3c23c0',
#   'LikelyOpen',
#   1238.0,
#   '/v3/places/4ffef79345b0986b7d3c23c0',
#   'Área Canina Polideportivo',
#   'C. Teresa Perales, 28100 Alcobendas Comunidad de Madrid',
#   40.538189,
#   -3.621384),
#  ('alcobendas',
#   'Park',
#   '4fd38676e4b0a071e1407b64',
#   'LikelyOpen',
#   1320.0,
#   '/v3/places/4fd38676e4b0a071e1407b64',
#   'Parque Infantil',
#   nan,
#   40.538756,
#   -3.620301),
#  ('alcobendas',
#   'Park',
#   '4fff4df9d63e295d76b70bad',
#   'LikelyOpen',
#   1407.0,
#   '/v3/places/4fff4df9d63e295d76b70bad',
#   'Área Canina Av. Ramón y Cajal',
#   '28700 San Sebastián de los Reyes Comunidad de Madrid',
#   40.543967,
#   -3.620011),
#  ('alcobendas',
#   'Park',
#   '4d46caec4e5d37046a830594',
#   'LikelyOpen',
#   1450.0,
#   '/v3/places/4d46caec4e5d37046a830594',
#   'Parque de Castilla-La Mancha',
#   'Comunidad de Madrid',
#   40.545937,
#   -3.651154),
#  ('alcobendas',
#   'Park',
#   '518298c1498e95fa18df54cc',
#   'LikelyOpen',
#   1451.0,
#   '/v3/places/518298c1498e95fa18df54cc',
#   'Parque Begonia Soto Moraleja',
#   'Moraleja Comunidad de Madrid',
#   40.527404,
#   -3.640362),
#  ('alcobendas',
#   'Park',
#   '51657ff3e4b01528d3dfe055',
#   'Unsure',
#   1561.0,
#   '/v3/places/51657ff3e4b01528d3dfe055',
#   'Chafalladas',
#   'Calle Marqués de la Valdavia, 101, 28100 Alcobendas Comunidad de Madrid',
#   40.546288,
#   -3.652386),
#  ('alcobendas',
#   'Park',
#   '4ed62f6630f813e77a9cdb77',
#   'LikelyOpen',
#   1591.0,
#   '/v3/places/4ed62f6630f813e77a9cdb77',
#   'Yonkis Park',
#   nan,
#   40.533665,
#   -3.65274),
#  ('alcobendas',
#   'Park',
#   '50afbf63e4b04cb0a19bc1ad',
#   'LikelyOpen',
#   1592.0,
#   '/v3/places/50afbf63e4b04cb0a19bc1ad',
#   'Club de Ajedrez V Centenario',
#   'San Sebastián de los Reyes Comunidad de Madrid',
#   40.554072,
#   -3.63222),
#  ('alcobendas',
#   'Park',
#   '4e70e96589987b9ce529a395',
#   'Unsure',
#   1610.0,
#   '/v3/places/4e70e96589987b9ce529a395',
#   'Parque de Extremadura',
#   'Alcobendas Comunidad de Madrid',
#   40.552423,
#   -3.644882),
#  ('alcobendas',
#   'Park',
#   '4f75cbdae4b0dbc5b645d1bb',
#   'LikelyOpen',
#   1615.0,
#   '/v3/places/4f75cbdae4b0dbc5b645d1bb',
#   'Parque Infantil y Ping Pong',
#   'Maestro Luna, s/n, 28100 Alcobendas Comunidad de Madrid',
#   40.553534,
#   -3.642877),
#  ('alcobendas',
#   'Park',
#   '51fcc630498eb5bc3d81cb09',
#   'LikelyOpen',
#   1650.0,
#   '/v3/places/51fcc630498eb5bc3d81cb09',
#   'Area de Ejercicios Para Mayores',
#   nan,
#   40.54371,
#   -3.65478),
#  ('alcobendas',
#   'Park',
#   '50744637e4b0b56e98ce9c64',
#   'LikelyOpen',
#   1669.0,
#   '/v3/places/50744637e4b0b56e98ce9c64',
#   'Cerro del Tambor',
#   'Cerro',
#   40.554497,
#   -3.641089),
#  ('alcobendas',
#   'Park',
#   '4c8285ced8086dcb7e597752',
#   'VeryLikelyOpen',
#   1684.0,
#   '/v3/places/4c8285ced8086dcb7e597752',
#   'Parque del Zoco las Pirámides',
#   'Madrid',
#   40.554359,
#   -3.629414),
#  ('alcobendas',
#   'Park',
#   'd1ef5c9d9ee743eaeee09056',
#   'LikelyOpen',
#   1684.0,
#   '/v3/places/d1ef5c9d9ee743eaeee09056',
#   'La Marina',
#   'Avenida Cataluña, 4 Bajo, 28703 San Sebastián de los Reyes Comunidad de Madrid',
#   40.553633,
#   -3.627114),
#  ('alcobendas',
#   'Park',
#   '4befc98ec601a593c1fcc2d1',
#   'LikelyOpen',
#   1714.0,
#   '/v3/places/4befc98ec601a593c1fcc2d1',
#   'Parque Av Valdelasfuentes',
#   'San Sebastián de los Reyes Comunidad de Madrid',
#   40.554841,
#   -3.641558),
#  ('alcobendas',
#   'Park',
#   '4f907990be77b06bd1a7a4d1',
#   'LikelyOpen',
#   1718.0,
#   '/v3/places/4f907990be77b06bd1a7a4d1',
#   'Área Canina Parque de Galicia',
#   'c/ Camilo José Cela, 28100 Alcobendas Comunidad de Madrid',
#   40.542364,
#   -3.655962),
#  ('alcobendas',
#   'Park',
#   '4ce386332407a1cdc8974ed0',
#   'VeryLikelyOpen',
#   1829.0,
#   '/v3/places/4ce386332407a1cdc8974ed0',
#   'Parque del Soto de la Moraleja',
#   '28108 Alcobendas Comunidad de Madrid',
#   40.524229,
#   -3.642011),
#  ('alcobendas',
#   'Park',
#   '4e627b872271573ad7a3b882',
#   'Unsure',
#   1845.0,
#   '/v3/places/4e627b872271573ad7a3b882',
#   'Área Canina Valdelasfuentes',
#   'Carlos Muñoz Ruíz, 28100 Alcobendas Comunidad de Madrid',
#   40.549492,
#   -3.653791),
#  ('alcobendas',
#   'Park',
#   '4ee4d4e9c2eee7f357b112f8',
#   'VeryLikelyOpen',
#   1887.0,
#   '/v3/places/4ee4d4e9c2eee7f357b112f8',
#   'Parque arroyo Valconejero',
#   'Paseo Albacete, s/n, 28701 San Sebastián de los Reyes Comunidad de Madrid',
#   40.556012,
#   -3.643209),
#  ('alcobendas',
#   'Park',
#   '4bf01e2dc8d920a1526f9430',
#   'VeryLikelyOpen',
#   1949.0,
#   '/v3/places/4bf01e2dc8d920a1526f9430',
#   'Parque Temático del Espacio',
#   'Dolores Ibarruri, 28100 Alcobendas Comunidad de Madrid',
#   40.551858,
#   -3.652867),
#  ('alcobendas',
#   'Park',
#   '56e4a6cc498ed68a8f79ee77',
#   'VeryLikelyOpen',
#   1971.0,
#   '/v3/places/56e4a6cc498ed68a8f79ee77',
#   'Parque Temático Poblado del Oeste',
#   '28100 Alcobendas Comunidad de Madrid',
#   40.547363,
#   -3.657146),
#  ('alcobendas',
#   'Park',
#   '26daa0ca8eaf4c1b6f4be56c',
#   'LikelyOpen',
#   497.0,
#   '/v3/places/26daa0ca8eaf4c1b6f4be56c',
#   'Parque de Félix Rodríguez de la Fuente',
#   'Alcobendas Madrid',
#   40.544395,
#   -3.637006),
#  ('alcobendas',
#   'Park',
#   '55ce39199ddf4873cb4ae0e6',
#   'LikelyOpen',
#   1348.0,
#   '/v3/places/55ce39199ddf4873cb4ae0e6',
#   'Parque de las Cepas',
#   'Madrid',
#   40.550344,
#   -3.644228),
#  ('alcobendas',
#   'Park',
#   '50caf509fa074232ca9612e5',
#   'Unsure',
#   1625.0,
#   '/v3/places/50caf509fa074232ca9612e5',
#   'Parque de la Marina',
#   '28700  Madrid',
#   40.553172,
#   -3.627463),
#  ('alcobendas',
#   'Monument',
#   '8effe272b7db4257c6b75538',
#   'LikelyOpen',
#   981.0,
#   '/v3/places/8effe272b7db4257c6b75538',
#   'Parroquia de Nuestra Señora de la Moraleja',
#   'Calle de Nardo, 44, 28108 Alcobendas Madrid',
#   40.53118,
#   -3.635774),
#  ('alcobendas',
#   'Monument',
#   '7d742596086641dbc1b7eb92',
#   'Unsure',
#   1396.0,
#   '/v3/places/7d742596086641dbc1b7eb92',
#   'Monumento a los Reyes Católicos',
#   'Calle de San Onofre, San Sebastián de los Reyes Madrid',
#   40.551389,
#   -3.628831),
#  ('alcobendas',
#   'TV Station',
#   '5375f3f4498e3437caae76f7',
#   'LikelyOpen',
#   766.0,
#   '/v3/places/5375f3f4498e3437caae76f7',
#   'Digi24',
#   'Calle de Anabel Segura, 14, Alcobendas Comunidad de Madrid',
#   40.533977,
#   -3.631447),
#  ('alcorcon',
#   'Park',
#   '4dee0a5e1520454e63d247cf',
#   'LikelyOpen',
#   925.0,
#   '/v3/places/4dee0a5e1520454e63d247cf',
#   'Parque Ciudad de Mayarí',
#   '28922 Alcorcón Comunidad de Madrid',
#   40.351753,
#   -3.837029),
#  ('alcorcon',
#   'Park',
#   '4c25d189a852c928be85e56c',
#   'LikelyOpen',
#   1857.0,
#   '/v3/places/4c25d189a852c928be85e56c',
#   'Parque de los Castillos',
#   'C/ de los Lirios, Alcorcón Comunidad de Madrid',
#   40.353488,
#   -3.807221),
#  ('alcorcon',
#   'Park',
#   '4cc86f6c3c40a35d47c9742e',
#   'VeryLikelyOpen',
#   1100.0,
#   '/v3/places/4cc86f6c3c40a35d47c9742e',
#   'La Ribota Park (Parque de La Ribota)',
#   'Alcorcón Comunidad de Madrid',
#   40.339584,
#   -3.830956),
#  ('alcorcon',
#   'Park',
#   '4cc6e4b101fb236af4bab9ba',
#   'VeryLikelyOpen',
#   719.0,
#   '/v3/places/4cc6e4b101fb236af4bab9ba',
#   'Parque las Comunidades',
#   'CL Pablo Iglesias, 28922 Alcorcón Comunidad de Madrid',
#   40.343556,
#   -3.832352),
#  ('alcorcon',
#   'Park',
#   '51e9e4be498e0fc0c3d1120c',
#   'LikelyOpen',
#   480.0,
#   '/v3/places/51e9e4be498e0fc0c3d1120c',
#   'Parque del Brasil',
#   nan,
#   40.348545,
#   -3.822839),
#  ('alcorcon',
#   'Park',
#   '4db4f1890437fa536a36d6b7',
#   'LikelyOpen',
#   583.0,
#   '/v3/places/4db4f1890437fa536a36d6b7',
#   'Parque San Petas',
#   'Calle Cisneros, 28922 Alcorcón Comunidad de Madrid',
#   40.344491,
#   -3.831195),
#  ('alcorcon',
#   'Park',
#   '4f535cfae4b07de37c8d709f',
#   'LikelyOpen',
#   782.0,
#   '/v3/places/4f535cfae4b07de37c8d709f',
#   'Parque Buero Vallejo',
#   'Los Robles, 28922 Alcorcón Comunidad de Madrid',
#   40.345622,
#   -3.836307),
#  ('alcorcon',
#   'Park',
#   '299bd266d531412c1a4ce7f8',
#   'LikelyOpen',
#   848.0,
#   '/v3/places/299bd266d531412c1a4ce7f8',
#   'Piko Park',
#   'Calle Valladolid, 13, 28922 Alcorcón Comunidad de Madrid',
#   40.341669,
#   -3.828782),
#  ('alcorcon',
#   'Park',
#   '56fc5650498ea26e37aec4f8',
#   'LikelyOpen',
#   852.0,
#   '/v3/places/56fc5650498ea26e37aec4f8',
#   'Parque Infantil',
#   'Calle Polvoranca, Alcorcón Comunidad de Madrid',
#   40.343519,
#   -3.821808),
#  ('alcorcon',
#   'Park',
#   '5193daef498e0126e66954e9',
#   'VeryLikelyOpen',
#   981.0,
#   '/v3/places/5193daef498e0126e66954e9',
#   'Zona de Ocio Infantil C. C Tres Aguas',
#   'Avenida Américas, 7 (C. C. Tres Aguas), Alcorcón Comunidad de Madrid',
#   40.357766,
#   -3.831753),
#  ('alcorcon',
#   'Park',
#   '4f735388e4b02c6aef3f1f8d',
#   'LikelyOpen',
#   1047.0,
#   '/v3/places/4f735388e4b02c6aef3f1f8d',
#   'Parque Infantil Recinto Ferial',
#   nan,
#   40.3407,
#   -3.823373),
#  ('alcorcon',
#   'Park',
#   '4f1c7139754a4cd5a26b7f8e',
#   'LikelyOpen',
#   1216.0,
#   '/v3/places/4f1c7139754a4cd5a26b7f8e',
#   'Parque de la Escuela de Música',
#   'Alcalde José Aranda, Alcorcón Comunidad de Madrid',
#   40.352284,
#   -3.814613),
#  ('alcorcon',
#   'Park',
#   '5131c2dbe4b0835c5fdc5463',
#   'LikelyOpen',
#   1319.0,
#   '/v3/places/5131c2dbe4b0835c5fdc5463',
#   'Parque de las Luces',
#   nan,
#   40.338607,
#   -3.835191),
#  ('alcorcon',
#   'Park',
#   '4f0486c4b8f7f476a54e5928',
#   'LikelyOpen',
#   1374.0,
#   '/v3/places/4f0486c4b8f7f476a54e5928',
#   'Parque de gama',
#   'Comunidad de Madrid',
#   40.348456,
#   -3.81224),
#  ('alcorcon',
#   'Park',
#   '4e4bd56dd4c0ae552d86e931',
#   'LikelyOpen',
#   1418.0,
#   '/v3/places/4e4bd56dd4c0ae552d86e931',
#   'Plaza de la Constitucion',
#   nan,
#   40.355643,
#   -3.812975),
#  ('alcorcon',
#   'Park',
#   '4db4040c81543d71da3cc224',
#   'LikelyOpen',
#   1460.0,
#   '/v3/places/4db4040c81543d71da3cc224',
#   'Parque de la República',
#   'Alcorcón Comunidad de Madrid',
#   40.337376,
#   -3.82117),
#  ('alcorcon',
#   'Park',
#   '50c077dfe4b0b88cce0fccd5',
#   'LikelyOpen',
#   1499.0,
#   '/v3/places/50c077dfe4b0b88cce0fccd5',
#   'Parque',
#   'Juan Ramón Jiménez',
#   40.336563,
#   -3.834288),
#  ('alcorcon',
#   'Park',
#   '4d49597a4509721eda2823b0',
#   'VeryLikelyOpen',
#   1712.0,
#   '/v3/places/4d49597a4509721eda2823b0',
#   'Parque Alfredo Nobel',
#   '28922 Alcorcón Comunidad de Madrid',
#   40.334705,
#   -3.834913),
#  ('alcorcon',
#   'Park',
#   '4f10b47ce4b0f2c21093bdc7',
#   'VeryLikelyOpen',
#   1938.0,
#   '/v3/places/4f10b47ce4b0f2c21093bdc7',
#   'Parque Darwin',
#   'Alcorcón Comunidad de Madrid',
#   40.332476,
#   -3.83447),
#  ('alcorcon',
#   'Park',
#   '1068685a11c5431fceec79d9',
#   'LikelyOpen',
#   1528.0,
#   '/v3/places/1068685a11c5431fceec79d9',
#   'Parque de Urtinsa',
#   'Alcorcón Madrid',
#   40.337747,
#   -3.818643),
#  ('alcorcon',
#   'Park',
#   '089266d6cb944537ed01848e',
#   'LikelyOpen',
#   1536.0,
#   '/v3/places/089266d6cb944537ed01848e',
#   'Parque de la República',
#   'Alcorcón Madrid',
#   40.336106,
#   -3.823003),
#  ('algete',
#   'Park',
#   '52d17ea5498e8d8980108104',
#   'LikelyOpen',
#   200.0,
#   '/v3/places/52d17ea5498e8d8980108104',
#   'África Park',
#   'Algete Comunidad de Madrid',
#   40.595217,
#   -3.499263),
#  ('algete',
#   'Park',
#   '4e82f2a8722e93408a930f0d',
#   'LikelyOpen',
#   265.0,
#   '/v3/places/4e82f2a8722e93408a930f0d',
#   'Parque de el Cigarral',
#   'Algete Comunidad de Madrid',
#   40.594084,
#   -3.498978),
#  ('algete',
#   'Park',
#   '4e63dc54d22d509a3a3d991e',
#   'VeryLikelyOpen',
#   462.0,
#   '/v3/places/4e63dc54d22d509a3a3d991e',
#   'Parque de los Olivos',
#   '28110 Algete Comunidad de Madrid',
#   40.597001,
#   -3.502799),
#  ('algete',
#   'Park',
#   '4cdfdb6c78ddf04dd840a398',
#   'LikelyOpen',
#   505.0,
#   '/v3/places/4cdfdb6c78ddf04dd840a398',
#   'Parque de las Fuentes',
#   '28110 Algete Comunidad de Madrid',
#   40.592373,
#   -3.494108),
#  ('algete',
#   'Park',
#   '4d32dcac8c42a1cdcfd2ec5d',
#   'LikelyOpen',
#   1744.0,
#   '/v3/places/4d32dcac8c42a1cdcfd2ec5d',
#   'Estanque de Patos Cobeña',
#   'Cobeña',
#   40.58106,
#   -3.503061),
#  ('alpedrete',
#   'Park',
#   '50b4698ae4b0151f15955aeb',
#   'LikelyOpen',
#   290.0,
#   '/v3/places/50b4698ae4b0151f15955aeb',
#   'Parque de las Columnas',
#   'Comunidad de Madrid',
#   40.657319,
#   -4.024587),
#  ('alpedrete',
#   'Park',
#   '60a100ac432b8d5266878389',
#   'VeryLikelyOpen',
#   622.0,
#   '/v3/places/60a100ac432b8d5266878389',
#   'Parque de Juegos',
#   'Carretera M-619 (En Frente De Caferería Feijoo), 28430 Alpedrete Comunidad de Madrid',
#   40.654997,
#   -4.021558),
#  ('alpedrete',
#   'Park',
#   '60a0ffe3da0dfb3d9f366d2b',
#   'VeryLikelyOpen',
#   629.0,
#   '/v3/places/60a0ffe3da0dfb3d9f366d2b',
#   'Parque de Juegos',
#   'Carretera M619 (En Frente De Cafetería Feijoo), 28430 Alpedrete Comunidad de Madrid',
#   40.655033,
#   -4.021312),
#  ('alpedrete',
#   'Monument',
#   'fa6253ac5cfa4365d7cd67d9',
#   'Unsure',
#   863.0,
#   '/v3/places/fa6253ac5cfa4365d7cd67d9',
#   'Estación de Alpedrete',
#   'Alpedrete',
#   40.658132,
#   -4.035099),
#  ('aranjuez',
#   'Park',
#   '4e8de8128b81f047f1a48bd7',
#   'LikelyOpen',
#   249.0,
#   '/v3/places/4e8de8128b81f047f1a48bd7',
#   'Parque Farnesio',
#   'Aranjuez Comunidad de Madrid',
#   40.033607,
#   -3.601662),
#  ('aranjuez',
#   'Park',
#   '51829e1a498efc5a67312305',
#   'LikelyOpen',
#   261.0,
#   '/v3/places/51829e1a498efc5a67312305',
#   'Parque Infantil Isabel de Farnesio',
#   nan,
#   40.033061,
#   -3.600978),
#  ('aranjuez',
#   'Park',
#   '4d68eef167a8f04df7f906be',
#   'VeryLikelyOpen',
#   393.0,
#   '/v3/places/4d68eef167a8f04df7f906be',
#   'Parque Pavia',
#   'Antigua carretera andalucia, 28300 Aranjuez Comunidad de Madrid',
#   40.031371,
#   -3.608458),
#  ('aranjuez',
#   'Park',
#   '4bcf26f1b221c9b68d6ad1d0',
#   'VeryLikelyOpen',
#   514.0,
#   '/v3/places/4bcf26f1b221c9b68d6ad1d0',
#   'Fuente del Negro',
#   'Aranjuez Comunidad de Madrid',
#   40.035829,
#   -3.607727),
#  ('aranjuez',
#   'Park',
#   '584d41faef787f34158d8d59',
#   'LikelyOpen',
#   701.0,
#   '/v3/places/584d41faef787f34158d8d59',
#   'Parque Infantil',
#   '28300 Aranjuez Comunidad de Madrid',
#   40.026591,
#   -3.600196),
#  ('aranjuez',
#   'Park',
#   '4fd8968ce4b01c6078ade14e',
#   'LikelyOpen',
#   736.0,
#   '/v3/places/4fd8968ce4b01c6078ade14e',
#   'Fuente del Reloj',
#   'Aranjuez Comunidad de Madrid',
#   40.037823,
#   -3.608564),
#  ('aranjuez',
#   'Park',
#   '51699267e4b036719336e027',
#   'LikelyOpen',
#   832.0,
#   '/v3/places/51699267e4b036719336e027',
#   'Parque Pozo de las Nieves',
#   nan,
#   40.028328,
#   -3.595588),
#  ('aranjuez',
#   'Park',
#   '51e2f2f0498e8da834c2afc4',
#   'LikelyOpen',
#   911.0,
#   '/v3/places/51e2f2f0498e8da834c2afc4',
#   'Parque Glorieta Nuevo Aranjuez',
#   'Aranjuez',
#   40.031668,
#   -3.593273),
#  ('aranjuez',
#   'Park',
#   '4f09c46ae4b09d21f7e7407d',
#   'LikelyOpen',
#   1216.0,
#   '/v3/places/4f09c46ae4b09d21f7e7407d',
#   'Parque infantil',
#   '28300 Aranjuez Comunidad de Madrid',
#   40.027463,
#   -3.591084),
#  ('aranjuez',
#   'Park',
#   '4f7f1c15e4b0fdf50018fddd',
#   'VeryLikelyOpen',
#   1248.0,
#   '/v3/places/4f7f1c15e4b0fdf50018fddd',
#   'Estanque de los Chinescos',
#   '28300 Aranjuez Comunidad de Madrid',
#   40.040451,
#   -3.59392),
#  ('aranjuez',
#   'Park',
#   '4e4d72f8d4c019a18a3b91eb',
#   'LikelyOpen',
#   1877.0,
#   '/v3/places/4e4d72f8d4c019a18a3b91eb',
#   'Urbanizacion los Jardines de Godoy',
#   'Aranjuez Comunidad de Madrid',
#   40.021518,
#   -3.621035),
#  ('aranjuez',
#   'Park',
#   'b21078f06c0c49b7de3fa95b',
#   'LikelyOpen',
#   702.0,
#   '/v3/places/b21078f06c0c49b7de3fa95b',
#   'Pooh y Sus Amigos Aranjuez',
#   'Calle San Fernando, 88, 28300 Aranjuez Madrid',
#   40.027931,
#   -3.597884),
#  ('aranjuez',
#   'Park',
#   'd3e27e53af0841935b9915ed',
#   'LikelyOpen',
#   1055.0,
#   '/v3/places/d3e27e53af0841935b9915ed',
#   'Entre Duendes y Hadas',
#   'Calle Santa Inés Nº 13, 28300 Aranjuez Madrid',
#   40.031743,
#   -3.591568),
#  ('aranjuez',
#   'Monument',
#   '1bc42868cb9d4d86b0faa6d4',
#   'LikelyOpen',
#   283.0,
#   '/v3/places/1bc42868cb9d4d86b0faa6d4',
#   'Casa de Caballeros y Oficios',
#   'Plaza de San Antonio, 28300 Aranjuez Madrid',
#   40.034045,
#   -3.60627),
#  ('aranjuez',
#   'Monument',
#   'f8484be22fe14a80d7359303',
#   'Unsure',
#   433.0,
#   '/v3/places/f8484be22fe14a80d7359303',
#   'Antiguo Hospital de San Carlos',
#   'Aranjuez Madrid',
#   40.029372,
#   -3.600473),
#  ('aranjuez',
#   'Monument',
#   '79769a51ba2d4d7a5a965e62',
#   'Unsure',
#   457.0,
#   '/v3/places/79769a51ba2d4d7a5a965e62',
#   'Fuente de Hercules y Anteo',
#   '28300 Aranjuez Madrid',
#   40.036164,
#   -3.605457),
#  ('aranjuez',
#   'Monument',
#   '7822883fb1bc49636f688355',
#   'Unsure',
#   553.0,
#   '/v3/places/7822883fb1bc49636f688355',
#   'Museo de las Faluas Reales',
#   'Calle de la Reina, s/n, 28300 Aranjuez Madrid',
#   40.035847,
#   -3.608404),
#  ('arganda-del-rey',
#   'Park',
#   '4d6938f51b63a1cd91bf3c2d',
#   'VeryLikelyOpen',
#   479.0,
#   '/v3/places/4d6938f51b63a1cd91bf3c2d',
#   'Parque Mirador',
#   '28500 Arganda del Rey Comunidad de Madrid',
#   40.296475,
#   -3.437499),
#  ('arganda-del-rey',
#   'Park',
#   '4e499cac45dd81ecad833ef6',
#   'LikelyOpen',
#   576.0,
#   '/v3/places/4e499cac45dd81ecad833ef6',
#   'Recinto Ferial Arganda',
#   'Arganda del Rey Comunidad de Madrid',
#   40.305795,
#   -3.436371),
#  ('arganda-del-rey',
#   'Park',
#   '500dbda2e4b0092313941db4',
#   'LikelyOpen',
#   627.0,
#   '/v3/places/500dbda2e4b0092313941db4',
#   'Parque de arganda',
#   'Comunidad de Madrid',
#   40.302919,
#   -3.444917),
#  ('arganda-del-rey',
#   'Park',
#   '4d332f13b609370405bffedf',
#   'LikelyOpen',
#   757.0,
#   '/v3/places/4d332f13b609370405bffedf',
#   'Parque Goleta',
#   nan,
#   40.293974,
#   -3.437339),
#  ('arganda-del-rey',
#   'Park',
#   '535f520b498e2cac4e931d9f',
#   'LikelyOpen',
#   832.0,
#   '/v3/places/535f520b498e2cac4e931d9f',
#   'Parque Adolfo Suárez',
#   '28500 Arganda del Rey Comunidad de Madrid',
#   40.295306,
#   -3.444786),
#  ('arganda-del-rey',
#   'Park',
#   '51d9bd65498e43b7762e03ff',
#   'LikelyOpen',
#   1245.0,
#   '/v3/places/51d9bd65498e43b7762e03ff',
#   'Parque Infantil',
#   nan,
#   40.300612,
#   -3.452764),
#  ('arganda-del-rey',
#   'Park',
#   '4e747338b61c22c637b95230',
#   'LikelyOpen',
#   1567.0,
#   '/v3/places/4e747338b61c22c637b95230',
#   'Parque infantil',
#   'Arganda del Rey Comunidad de Madrid',
#   40.309577,
#   -3.452475),
#  ('arganda-del-rey',
#   'Park',
#   '674b48da66e7475ed0e7e22a',
#   'LikelyOpen',
#   26.0,
#   '/v3/places/674b48da66e7475ed0e7e22a',
#   'Parque Natural las Lagunas',
#   'Carretera Chinchón M-313, Km 1,8, 28500 Arganda del Rey Madrid',
#   40.300988,
#   -3.437951),
#  ('batres',
#   'Park',
#   '4eb535820aaf1abedf2f47b5',
#   'LikelyOpen',
#   74.0,
#   '/v3/places/4eb535820aaf1abedf2f47b5',
#   'Plaza Arenal',
#   'Comunidad de Madrid',
#   40.2095,
#   -3.922333),
#  ('batres',
#   'Castle',
#   '5229a363bce685ed45b13e83',
#   'VeryLikelyOpen',
#   259.0,
#   '/v3/places/5229a363bce685ed45b13e83',
#   'Castillo de Batres',
#   'Crta. M-404, 28976 Batres Comunidad de Madrid',
#   40.210979,
#   -3.923474),
#  ('becerril-de-la-sierra',
#   'Park',
#   '5f40f1ab4af8554dc9823110',
#   'LikelyOpen',
#   703.0,
#   '/v3/places/5f40f1ab4af8554dc9823110',
#   'Parque',
#   '28490 Becerril de la Sierra Comunidad de Madrid',
#   40.710478,
#   -3.985896),
#  ('becerril-de-la-sierra',
#   'Park',
#   '4f203994e4b03be7a56428aa',
#   'LikelyOpen',
#   1950.0,
#   '/v3/places/4f203994e4b03be7a56428aa',
#   'Parque de la Tejera',
#   '28490 Becerril de la Sierra Comunidad de Madrid',
#   40.704664,
#   -4.006358),
#  ('boadilla-del-monte',
#   'Park',
#   '4e31a566483b1bbfc5b00423',
#   'VeryLikelyOpen',
#   1548.0,
#   '/v3/places/4e31a566483b1bbfc5b00423',
#   'Monte de Boadilla',
#   '28223 Boadilla del Monte Comunidad de Madrid',
#   40.410202,
#   -3.859313),
#  ('boadilla-del-monte',
#   'Park',
#   '005c2228b0f042b6050d9044',
#   'LikelyOpen',
#   98.0,
#   '/v3/places/005c2228b0f042b6050d9044',
#   'Diveruca',
#   'Avenida del Generalísimo Nº 25, 28660 Boadilla del Monte Comunidad de Madrid',
#   40.406117,
#   -3.875887),
#  ('boadilla-del-monte',
#   'Park',
#   '4e2c794fd4c0e5c89acfa8fc',
#   'LikelyOpen',
#   304.0,
#   '/v3/places/4e2c794fd4c0e5c89acfa8fc',
#   'Parque Juan Pablo II',
#   'Boadilla del Monte Comunidad de Madrid',
#   40.402612,
#   -3.876513),
#  ('boadilla-del-monte',
#   'Park',
#   '5a9c2fb5b9ac3832c40affbd',
#   'LikelyOpen',
#   352.0,
#   '/v3/places/5a9c2fb5b9ac3832c40affbd',
#   'Parque de el Nacedero',
#   '28660 Boadilla del Monte Comunidad de Madrid',
#   40.403932,
#   -3.872743),
#  ('boadilla-del-monte',
#   'Park',
#   '548c1904498e7cd8fd940ce1',
#   'LikelyOpen',
#   434.0,
#   '/v3/places/548c1904498e7cd8fd940ce1',
#   'Parque Boadilla Centro',
#   nan,
#   40.407522,
#   -3.880738),
#  ('boadilla-del-monte',
#   'Park',
#   '4e907a7ef5b9f8967cb47d6b',
#   'LikelyOpen',
#   524.0,
#   '/v3/places/4e907a7ef5b9f8967cb47d6b',
#   'Parque Santillana del Mar',
#   '28660 Boadilla del Monte Comunidad de Madrid',
#   40.407518,
#   -3.881965),
#  ('boadilla-del-monte',
#   'Park',
#   '4fbe57e7e4b00c059c69bef1',
#   'LikelyOpen',
#   529.0,
#   '/v3/places/4fbe57e7e4b00c059c69bef1',
#   'Parque Palacio Boadilla',
#   nan,
#   40.406456,
#   -3.870382),
#  ('boadilla-del-monte',
#   'Park',
#   '507304a7e4b00022a2a2b853',
#   'LikelyOpen',
#   621.0,
#   '/v3/places/507304a7e4b00022a2a2b853',
#   'Parque la Alberca',
#   'Alberca',
#   40.407,
#   -3.883485),
#  ('boadilla-del-monte',
#   'Park',
#   '4f5a426ae4b030058576f596',
#   'LikelyOpen',
#   1360.0,
#   '/v3/places/4f5a426ae4b030058576f596',
#   'Parque Victoria Rubio',
#   'Rubio',
#   40.40996,
#   -3.891362),
#  ('boadilla-del-monte',
#   'Park',
#   '4ea3eec52c5b5cb4f49de982',
#   'LikelyOpen',
#   1380.0,
#   '/v3/places/4ea3eec52c5b5cb4f49de982',
#   'Parque Gregorio Marañón',
#   'Gregorio Marañon, Boadilla del Monte Comunidad de Madrid',
#   40.406346,
#   -3.892723),
#  ('boadilla-del-monte',
#   'Park',
#   '5243074211d2345b0e3e8a84',
#   'LikelyOpen',
#   1478.0,
#   '/v3/places/5243074211d2345b0e3e8a84',
#   'Zona de Juegos Siglo XXI',
#   nan,
#   40.405637,
#   -3.893939),
#  ('boadilla-del-monte',
#   'Park',
#   '4e9aa7688b81c0254e6deaec',
#   'LikelyOpen',
#   1480.0,
#   '/v3/places/4e9aa7688b81c0254e6deaec',
#   'Parque Villa de Pons',
#   'Madrid Comunidad de Madrid',
#   40.411649,
#   -3.891881),
#  ('boadilla-del-monte',
#   'Park',
#   '4e904e70b63456ab955d94c0',
#   'LikelyOpen',
#   1480.0,
#   '/v3/places/4e904e70b63456ab955d94c0',
#   'Parque Severo Ochoa',
#   'Severo Ochoa, 1, 28660 Boadilla del Monte Comunidad de Madrid',
#   40.411649,
#   -3.891881),
#  ('boadilla-del-monte',
#   'Park',
#   '4f5a2edfe4b07f0bf658c7a0',
#   'LikelyOpen',
#   1486.0,
#   '/v3/places/4f5a2edfe4b07f0bf658c7a0',
#   'Parque Alejandro de la Sota',
#   nan,
#   40.399525,
#   -3.892285),
#  ('boadilla-del-monte',
#   'Park',
#   '507148c7e4b0f3224343a1e1',
#   'LikelyOpen',
#   1500.0,
#   '/v3/places/507148c7e4b0f3224343a1e1',
#   'recinto canino Boadilla',
#   nan,
#   40.414533,
#   -3.863473),
#  ('boadilla-del-monte',
#   'Park',
#   '4dc1850752b1877d85b5e1f0',
#   'VeryLikelyOpen',
#   1554.0,
#   '/v3/places/4dc1850752b1877d85b5e1f0',
#   'Parque (de Colores) Victimas del Terrorismo',
#   'Calle Juan de la Cierva, Boadilla del Monte Comunidad de Madrid',
#   40.409952,
#   -3.893818),
#  ('boadilla-del-monte',
#   'Park',
#   '506b0450e4b01ca2efa7c159',
#   'LikelyOpen',
#   1775.0,
#   '/v3/places/506b0450e4b01ca2efa7c159',
#   'Parque Hermanos Machado',
#   'Comunidad de Madrid',
#   40.409029,
#   -3.896886),
#  ('boadilla-del-monte',
#   'Park',
#   '4ea049f061af1289b80a257a',
#   'LikelyOpen',
#   1821.0,
#   '/v3/places/4ea049f061af1289b80a257a',
#   'Parque Jorge Manrique, Condesa de Chinchon',
#   'Jorge Manrique, Boadilla del Monte Comunidad de Madrid',
#   40.400198,
#   -3.896906),
#  ('boadilla-del-monte',
#   'Park',
#   '506afb24e4b0c5eb9efa4f6b',
#   'LikelyOpen',
#   1849.0,
#   '/v3/places/506afb24e4b0c5eb9efa4f6b',
#   'Parque Azorín',
#   'Calle Jacinto Benavente, 28660 Boadilla del Monte Comunidad de Madrid',
#   40.404875,
#   -3.898319),
#  ('boadilla-del-monte',
#   'Park',
#   '4c488dc8972c0f477d6d2721',
#   'LikelyOpen',
#   1939.0,
#   '/v3/places/4c488dc8972c0f477d6d2721',
#   'Parque Infantil Miguel Hernandez',
#   nan,
#   40.409093,
#   -3.898851),
#  ('boadilla-del-monte',
#   'Park',
#   '1847b735d4da402765f2e033',
#   'Unsure',
#   1800.0,
#   '/v3/places/1847b735d4da402765f2e033',
#   'Pereda Gestion',
#   'Avenida Cantabria Ciudad Grupo Santander, s/n, 28660 Boadilla del Monte Madrid',
#   40.394176,
#   -3.861051),
#  ('boadilla-del-monte',
#   'Monument',
#   '4c0251e6f423a593919bce16',
#   'VeryLikelyOpen',
#   68.0,
#   '/v3/places/4c0251e6f423a593919bce16',
#   'Palacio del Infante don Luis (Boadilla del Monte)',
#   'Avenida de Adolfo Suárez, s/n, 28660 Boadilla del Monte Comunidad de Madrid',
#   40.405905,
#   -3.876129),
#  ('boadilla-del-monte',
#   'TV Station',
#   '4e9d7f7f5503b4a7c1454e43',
#   'LikelyOpen',
#   1809.0,
#   '/v3/places/4e9d7f7f5503b4a7c1454e43',
#   '13 Tv',
#   'Calle de Francisco Tomas y Valiente, s/n, 28660 Boadilla del Monte Comunidad de Madrid',
#   40.414083,
#   -3.89454),
#  ('boalo-el',
#   'Park',
#   '4eac56d95c5cf8848b132342',
#   'LikelyOpen',
#   1294.0,
#   '/v3/places/4eac56d95c5cf8848b132342',
#   'Parque Municipal del Boalo',
#   'Boalo',
#   40.713575,
#   -3.90567),
#  ('boalo-el',
#   'Park',
#   '4dd00f22fa7664b7c6cfde13',
#   'LikelyOpen',
#   1946.0,
#   '/v3/places/4dd00f22fa7664b7c6cfde13',
#   'Parque la Ponderosa de la Sierra',
#   nan,
#   40.723615,
#   -3.941794),
#  ('boalo-el',
#   'Monument',
#   '4e17239ac65be9c55e8bbd83',
#   'LikelyOpen',
#   1883.0,
#   '/v3/places/4e17239ac65be9c55e8bbd83',
#   'El Quinto Pino',
#   'Pino',
#   40.703379,
#   -3.932901),
#  ('braojos',
#   'Monument',
#   '4a470120ec564dc5ff1fae09',
#   'LikelyOpen',
#   72.0,
#   '/v3/places/4a470120ec564dc5ff1fae09',
#   'Ayuntamiento Braojos de la Sierra',
#   'Braojos Madrid',
#   41.039387,
#   -3.642364),
#  ('brunete',
#   'Park',
#   '544250f1498e7e5e625df169',
#   'LikelyOpen',
#   109.0,
#   '/v3/places/544250f1498e7e5e625df169',
#   'parque municipal de Brunete',
#   nan,
#   40.40407,
#   -3.997822),
#  ('brunete',
#   'Park',
#   '5478b475498e43be5a4967ba',
#   'LikelyOpen',
#   329.0,
#   '/v3/places/5478b475498e43be5a4967ba',
#   'Castilandia',
#   'Calle Tahona, 3, 28690 Brunete Comunidad de Madrid',
#   40.403878,
#   -4.001505),
#  ('buitrago-del-lozoya',
#   'Park',
#   '4d7146137726a1cd8fe34fd2',
#   'LikelyOpen',
#   1780.0,
#   '/v3/places/4d7146137726a1cd8fe34fd2',
#   'Parque de las Avenidas',
#   '09006 Burgos Burgos',
#   41.011284,
#   -3.632806),
#  ('buitrago-del-lozoya',
#   'Monument',
#   '4e3ef1b062e19d610982b839',
#   'VeryLikelyOpen',
#   112.0,
#   '/v3/places/4e3ef1b062e19d610982b839',
#   'Castillo de Buitrago de Lozoya',
#   'Plaza del Castillo, s/n, 28730 Buitrago del Lozoya Comunidad de Madrid',
#   40.994635,
#   -3.633966),
#  ('buitrago-del-lozoya',
#   'Monument',
#   '5e3ff99457fcde00081e69b9',
#   'VeryLikelyOpen',
#   81.0,
#   '/v3/places/5e3ff99457fcde00081e69b9',
#   'Muralla de Buitrago del Lozoya',
#   'Calle del Arco, 10, 28730 Buitrago del Lozoya Comunidad de Madrid',
#   40.994754,
#   -3.635614),
#  ('buitrago-del-lozoya',
#   'Monument',
#   '467824636f19476b465924ea',
#   'Unsure',
#   1920.0,
#   '/v3/places/467824636f19476b465924ea',
#   'Embalse de Riosequillo',
#   'Lozoya Madrid',
#   40.982857,
#   -3.650882),
#  ('bustarviejo',
#   'Park',
#   '4fef7535e4b018055be092d0',
#   'LikelyOpen',
#   196.0,
#   '/v3/places/4fef7535e4b018055be092d0',
#   'Parque de arriba',
#   'Calle De La Cerca, Bustarviejo',
#   40.860178,
#   -3.711186),
#  ('cabanillas-de-la-sierra',
#   'Park',
#   '4e749599aeb780be09d032e9',
#   'LikelyOpen',
#   886.0,
#   '/v3/places/4e749599aeb780be09d032e9',
#   'Paint Ball Cabanillas',
#   'Cabanillas',
#   40.823918,
#   -3.636061),
#  ('cabanillas-de-la-sierra',
#   'Monument',
#   '9b5dda24716b44de8f09486d',
#   'LikelyOpen',
#   138.0,
#   '/v3/places/9b5dda24716b44de8f09486d',
#   'Iglesia Parroquial de San Juan Bautista',
#   'Cabanillas de la Sierra Madrid',
#   40.821107,
#   -3.624473),
#  ('camarma-de-esteruelas',
#   'Park',
#   '4c4181c9af052d7f16777d79',
#   'VeryLikelyOpen',
#   400.0,
#   '/v3/places/4c4181c9af052d7f16777d79',
#   'Parque Arroyo Fresno',
#   'Arroyo Fresno, 13, Madrid Comunidad de Madrid',
#   40.549927,
#   -3.374025),
#  ('camarma-de-esteruelas',
#   'Park',
#   '4d6e920f134ea143ae92921a',
#   'VeryLikelyOpen',
#   1864.0,
#   '/v3/places/4d6e920f134ea143ae92921a',
#   'Alba - Asociación Para la Liberación y el Bienestar Animal',
#   'Camino del Carral, 32, 28816 Camarma de Esteruelas Comunidad de Madrid',
#   40.540581,
#   -3.397694),
#  ('cercedilla',
#   'Park',
#   '5076ccbce4b0eca51a2d5c91',
#   'Unsure',
#   94.0,
#   '/v3/places/5076ccbce4b0eca51a2d5c91',
#   'La Titiriteka',
#   'Calle de los Registros, 21, 28470 Cercedilla Comunidad de Madrid',
#   40.741728,
#   -4.056769),
#  ('cercedilla',
#   'Park',
#   '506814e5e4b05564fc0c133e',
#   'VeryLikelyOpen',
#   649.0,
#   '/v3/places/506814e5e4b05564fc0c133e',
#   'Parque PradoLuengo',
#   'PradoLuengo',
#   40.737839,
#   -4.062021),
#  ('cercedilla',
#   'Monument',
#   '4f536378e4b0c416056a97d1',
#   'VeryLikelyOpen',
#   841.0,
#   '/v3/places/4f536378e4b0c416056a97d1',
#   'Centro Hípico los Ciruelos',
#   'Camino de los Ciruelos, 22, 28470 Cercedilla Comunidad de Madrid',
#   40.752492,
#   -4.054415),
#  ('cercedilla',
#   'Monument',
#   '54bd11d087cd4c7f52c9830f',
#   'LikelyOpen',
#   24.0,
#   '/v3/places/54bd11d087cd4c7f52c9830f',
#   'Museo del Esquí',
#   'Plaza Mayor, 3, 28470 Cercedilla Madrid',
#   40.741482,
#   -4.055639),
#  ('cercedilla',
#   'Monument',
#   '9f364c1253b942640d66c05c',
#   'Unsure',
#   112.0,
#   '/v3/places/9f364c1253b942640d66c05c',
#   'Miradores de los poetas',
#   'Cercedilla Madrid',
#   40.74071,
#   -4.056887),
#  ('chapineria',
#   'Monument',
#   '7224f2498be74cf07d36fde9',
#   'LikelyOpen',
#   186.0,
#   '/v3/places/7224f2498be74cf07d36fde9',
#   'Palacio de la Sagra',
#   'Calle de Prudencio Melo, s/n, 28694 Chapinería Madrid',
#   40.3775,
#   -4.209998),
#  ('chinchon',
#   'Park',
#   '51f6b429498ee52b46de5048',
#   'LikelyOpen',
#   707.0,
#   '/v3/places/51f6b429498ee52b46de5048',
#   'Parque Valquejigoso',
#   'Chinchón Comunidad de Madrid',
#   40.13458,
# ...
#   '/v3/places/4d6a35dd2acd6ea864b143c0',
#   'Parque Infantil Descubridores 1',
#   nan,
#   40.609678,
#   -3.714676),
#  ('tres-cantos',
#   'Park',
#   '4f21779ee4b0c3e5ef253ad0',
#   'LikelyOpen',
#   786.0,
#   '/v3/places/4f21779ee4b0c3e5ef253ad0',
#   'Parque Infantil Pza Constitucion',
#   'Tres Cantos Comunidad de Madrid',
#   40.599933,
#   -3.709735),
#  ('tres-cantos',
#   'Park',
#   '4e0c9da66284f2bbda5ae395',
#   'LikelyOpen',
#   865.0,
#   '/v3/places/4e0c9da66284f2bbda5ae395',
#   'Palmera Saharaui',
#   'Avda del Parque, 28760 Tres Cantos Comunidad de Madrid',
#   40.608476,
#   -3.716489),
#  ('tres-cantos',
#   'Park',
#   '4d63e80ea45b548118e8062d',
#   'LikelyOpen',
#   1009.0,
#   '/v3/places/4d63e80ea45b548118e8062d',
#   'Parque Infantil Artesanos 2',
#   'Artesanos, 64, Tres Cantos Comunidad de Madrid',
#   40.615313,
#   -3.709837),
#  ('tres-cantos',
#   'Park',
#   '525bdbe311d2bece4f937855',
#   'Unsure',
#   1011.0,
#   '/v3/places/525bdbe311d2bece4f937855',
#   'Embarcaciones',
#   'Comunidad de Madrid',
#   40.597946,
#   -3.702744),
#  ('tres-cantos',
#   'Park',
#   '4dadc8a66a23037eec97bff3',
#   'LikelyOpen',
#   1038.0,
#   '/v3/places/4dadc8a66a23037eec97bff3',
#   'Parque Infantil Embarcaciones 4',
#   'Tres Cantos Comunidad de Madrid',
#   40.597743,
#   -3.702522),
#  ('tres-cantos',
#   'Park',
#   '4fba70597beb503189b7f71a',
#   'LikelyOpen',
#   1223.0,
#   '/v3/places/4fba70597beb503189b7f71a',
#   'El caballito de Laura',
#   'Calle del Fuego, 1, 28770 Tres Cantos Comunidad de Madrid',
#   40.61324,
#   -3.718085),
#  ('tres-cantos',
#   'Park',
#   '4d9b18f93a32a093ef688a19',
#   'LikelyOpen',
#   1368.0,
#   '/v3/places/4d9b18f93a32a093ef688a19',
#   'Parque',
#   nan,
#   40.611853,
#   -3.691872),
#  ('tres-cantos',
#   'Park',
#   '55199ca7498efa51483c6a4d',
#   'LikelyOpen',
#   1484.0,
#   '/v3/places/55199ca7498efa51483c6a4d',
#   'Parque de las Siete Leguas',
#   'Comunidad de Madrid',
#   40.613773,
#   -3.721316),
#  ('tres-cantos',
#   'Park',
#   '4dc96df9d164c28eea836b09',
#   'LikelyOpen',
#   1531.0,
#   '/v3/places/4dc96df9d164c28eea836b09',
#   'Mini Parque',
#   'Calle del Tagarral, 10, 28760 Tres Cantos Comunidad de Madrid',
#   40.593553,
#   -3.700608),
#  ('tres-cantos',
#   'Park',
#   '520a60a111d2957a64b70fb5',
#   'LikelyOpen',
#   1540.0,
#   '/v3/places/520a60a111d2957a64b70fb5',
#   'Parque Sector Islas',
#   nan,
#   40.592973,
#   -3.703003),
#  ('tres-cantos',
#   'Park',
#   '4bf96cc55317a593b63b017f',
#   'LikelyOpen',
#   1554.0,
#   '/v3/places/4bf96cc55317a593b63b017f',
#   'Parque Infantil',
#   nan,
#   40.593134,
#   -3.701476),
#  ('tres-cantos',
#   'Park',
#   '5221e29811d2729e83a4eda8',
#   'LikelyOpen',
#   1926.0,
#   '/v3/places/5221e29811d2729e83a4eda8',
#   'Parque de los Alcornocales',
#   'Comunidad de Madrid',
#   40.591478,
#   -3.700334),
#  ('tres-cantos',
#   'Monument',
#   'a9deccfd435e41a09f75676d',
#   'LikelyOpen',
#   1597.0,
#   '/v3/places/a9deccfd435e41a09f75676d',
#   'Castillo de Soto de Vinuelas',
#   'Tres Cantos Comunidad de Madrid',
#   40.611976,
#   -3.688979),
#  ('tres-cantos',
#   'Monument',
#   'bb4ed48c6a07466240cedbc7',
#   'LikelyOpen',
#   577.0,
#   '/v3/places/bb4ed48c6a07466240cedbc7',
#   'ACTION LIVE Tres Cantos',
#   'Tres Cantos Madrid',
#   40.609043,
#   -3.712564),
#  ('tres-cantos',
#   'Monument',
#   '73d2976576564f037faddb22',
#   'LikelyOpen',
#   1085.0,
#   '/v3/places/73d2976576564f037faddb22',
#   'Plaza de la Estación',
#   '28760 Tres Cantos Madrid',
#   40.599278,
#   -3.715078),
#  ('tres-cantos',
#   'TV Station',
#   '55aadd3a498e17c485179839',
#   'LikelyOpen',
#   1113.0,
#   '/v3/places/55aadd3a498e17c485179839',
#   'Movistar',
#   'Tres Cantos Comunidad de Madrid',
#   40.599107,
#   -3.697953),
#  ('tres-cantos',
#   'TV Station',
#   '53b2d576e8224244a959f496',
#   'LikelyOpen',
#   1125.0,
#   '/v3/places/53b2d576e8224244a959f496',
#   'Dts Distribuidora de Television Digital',
#   'Avenida Artesanos, 6, 28760 Tres Cantos Comunidad de Madrid',
#   40.598462,
#   -3.698764),
#  ('tres-cantos',
#   'TV Station',
#   'd9c0258ea8fc4cab2d6275fd',
#   'Unsure',
#   1106.0,
#   '/v3/places/d9c0258ea8fc4cab2d6275fd',
#   'Canal Satelite Digital',
#   'Avenida Artesanos, 6, 28760 Tres Cantos Madrid',
#   40.598587,
#   -3.698711),
#  ('valdemaqueda',
#   'Monument',
#   '5214dcbf97da4b384e2441d1',
#   'Unsure',
#   1002.0,
#   '/v3/places/5214dcbf97da4b384e2441d1',
#   'Puente Mocha',
#   'Valdemaqueda Madrid',
#   40.502246,
#   -4.300479),
#  ('valdemorillo',
#   'Monument',
#   '4e6c1bea1495f34925691187',
#   'VeryLikelyOpen',
#   445.0,
#   '/v3/places/4e6c1bea1495f34925691187',
#   'Plaza de toros la Candelaria Valdemorillo',
#   '28210 Valdemorillo Comunidad de Madrid',
#   40.497991,
#   -4.069579),
#  ('valdemoro',
#   'Park',
#   '4e652e82ae60e9edf6ebaf32',
#   'LikelyOpen',
#   1148.0,
#   '/v3/places/4e652e82ae60e9edf6ebaf32',
#   'Los Lagos',
#   'Valdemoro Comunidad de Madrid',
#   40.183308,
#   -3.682841),
#  ('valdemoro',
#   'Park',
#   '4c0a9ab76071a59353dadf32',
#   'VeryLikelyOpen',
#   487.0,
#   '/v3/places/4c0a9ab76071a59353dadf32',
#   'Parque Enrique Tierno Galván',
#   'Valdemoro Comunidad de Madrid',
#   40.185893,
#   -3.675653),
#  ('valdemoro',
#   'Park',
#   '622c99947707736f718156c1',
#   'VeryLikelyOpen',
#   580.0,
#   '/v3/places/622c99947707736f718156c1',
#   'Parque Forestal Cerro del Castillo',
#   '28343 Valdemoro Comunidad de Madrid',
#   40.194067,
#   -3.670847),
#  ('valdemoro',
#   'Park',
#   '4de94ef47d8b02ee9f2ca631',
#   'LikelyOpen',
#   626.0,
#   '/v3/places/4de94ef47d8b02ee9f2ca631',
#   'Parque Nuestra Señora de Monserrat',
#   'Paseo de la estacion, 28340 Valdemoro Comunidad de Madrid',
#   40.193014,
#   -3.666407),
#  ('valdemoro',
#   'Park',
#   '4e88a4a9775b68cb831a5f26',
#   'LikelyOpen',
#   628.0,
#   '/v3/places/4e88a4a9775b68cb831a5f26',
#   'Parque de Extremadura',
#   nan,
#   40.193256,
#   -3.666763),
#  ('valdemoro',
#   'Park',
#   '5198edeb498e01d90691fcf4',
#   'LikelyOpen',
#   641.0,
#   '/v3/places/5198edeb498e01d90691fcf4',
#   'Parque Enrique Tierno Galván',
#   'Comunidad de Madrid',
#   40.188233,
#   -3.678942),
#  ('valdemoro',
#   'Park',
#   '57385391498ee39bab92b8b9',
#   'LikelyOpen',
#   793.0,
#   '/v3/places/57385391498ee39bab92b8b9',
#   'Parque Perros Agility',
#   nan,
#   40.195936,
#   -3.670138),
#  ('valdemoro',
#   'Park',
#   '4e4eb3ddd164978659bfa738',
#   'VeryLikelyOpen',
#   794.0,
#   '/v3/places/4e4eb3ddd164978659bfa738',
#   'Parque Duque de Ahumada',
#   'Calle Libertad Numero, 1, 28040 Valdemoro Comunidad de Madrid',
#   40.189898,
#   -3.681218),
#  ('valdemoro',
#   'Park',
#   '4ec140ad93ad36d7a9b2862e',
#   'LikelyOpen',
#   870.0,
#   '/v3/places/4ec140ad93ad36d7a9b2862e',
#   'Parque Infantil Hojarasca',
#   nan,
#   40.18424,
#   -3.679704),
#  ('valdemoro',
#   'Park',
#   '4e82e98ad3e37ba06ecd9b7a',
#   'LikelyOpen',
#   872.0,
#   '/v3/places/4e82e98ad3e37ba06ecd9b7a',
#   'Parque de las Sombras',
#   nan,
#   40.189838,
#   -3.681624),
#  ('valdemoro',
#   'Park',
#   '534677b2498e4a24df6368c7',
#   'VeryLikelyOpen',
#   1002.0,
#   '/v3/places/534677b2498e4a24df6368c7',
#   'Parque de las Víctimas del Terrorismo',
#   '28340 Valdemoro Comunidad de Madrid',
#   40.195431,
#   -3.67958),
#  ('valdemoro',
#   'Park',
#   '4ec62f5077c8be49210e01ca',
#   'VeryLikelyOpen',
#   1111.0,
#   '/v3/places/4ec62f5077c8be49210e01ca',
#   'Parque de los Olivos',
#   nan,
#   40.178887,
#   -3.670512),
#  ('valdemoro',
#   'Park',
#   '61af54fab1a341fbb8f127e8',
#   'LikelyOpen',
#   1126.0,
#   '/v3/places/61af54fab1a341fbb8f127e8',
#   'Parque España',
#   'Valdemoro Comunidad de Madrid',
#   40.18167,
#   -3.680783),
#  ('valdemoro',
#   'Park',
#   '4e231fb922717a5245dbf345',
#   'VeryLikelyOpen',
#   1141.0,
#   '/v3/places/4e231fb922717a5245dbf345',
#   'Parque Bolitas del Airón',
#   'Paseo del Prado, s/n, 28343 Valdemoro Comunidad de Madrid',
#   40.191593,
#   -3.658462),
#  ('valdemoro',
#   'Park',
#   '4e9072195c5c4562effeea7c',
#   'LikelyOpen',
#   1424.0,
#   '/v3/places/4e9072195c5c4562effeea7c',
#   'Parque de las Eras',
#   'Valdemoro Comunidad de Madrid',
#   40.197302,
#   -3.684058),
#  ('valdemoro',
#   'Park',
#   '4e823b217beb302d96f2f2cc',
#   'LikelyOpen',
#   1577.0,
#   '/v3/places/4e823b217beb302d96f2f2cc',
#   'Guanta',
#   '28341 Valdemoro Comunidad de Madrid',
#   40.189135,
#   -3.690005),
#  ('valdemoro',
#   'Park',
#   '4db562290f2cc52c2110f7cc',
#   'LikelyOpen',
#   1673.0,
#   '/v3/places/4db562290f2cc52c2110f7cc',
#   'Parque Adolfo Suárez',
#   'Antonio Van de Per, 28342 Valdemoro Comunidad de Madrid',
#   40.197692,
#   -3.687404),
#  ('valdemoro',
#   'Park',
#   '4f593ca7e4b07f0bf59940fb',
#   'LikelyOpen',
#   1676.0,
#   '/v3/places/4f593ca7e4b07f0bf59940fb',
#   'Playground',
#   nan,
#   40.197617,
#   -3.687511),
#  ('valdemoro',
#   'Park',
#   '4ecfa77ecc219860f67f592c',
#   'LikelyOpen',
#   1996.0,
#   '/v3/places/4ecfa77ecc219860f67f592c',
#   'Avd. del Mar Adriatico',
#   nan,
#   40.175938,
#   -3.687765),
#  ('valdemoro',
#   'Park',
#   '20dc164956194d251ae6f723',
#   'Unsure',
#   1027.0,
#   '/v3/places/20dc164956194d251ae6f723',
#   'Parque de las Eras',
#   nan,
#   40.193437,
#   -3.681943),
#  ('valdemoro',
#   'Park',
#   '340a939d4c974cddb19bc60e',
#   'LikelyOpen',
#   1528.0,
#   '/v3/places/340a939d4c974cddb19bc60e',
#   'Ludoteca Chia Junior',
#   'Avenida Hispanoamérica, 50, 28341 Valdemoro Madrid',
#   40.186211,
#   -3.689097),
#  ('valdemoro',
#   'Park',
#   '8a460ce6511b485cd89c9ecf',
#   'Unsure',
#   1528.0,
#   '/v3/places/8a460ce6511b485cd89c9ecf',
#   'Actilud Infantiles',
#   'Avenida Hispano América, 50, 28341 Valdemoro Madrid',
#   40.186211,
#   -3.689097),
#  ('valverde-de-alcala',
#   'Park',
#   '5c2229e2f427de002c86d4e9',
#   'LikelyOpen',
#   1598.0,
#   '/v3/places/5c2229e2f427de002c86d4e9',
#   'Parque de la Hontanilla',
#   '28810 Villalbilla Comunidad de Madrid',
#   40.431979,
#   -3.295011),
#  ('villalbilla',
#   'Park',
#   '5c2229e2f427de002c86d4e9',
#   'LikelyOpen',
#   321.0,
#   '/v3/places/5c2229e2f427de002c86d4e9',
#   'Parque de la Hontanilla',
#   '28810 Villalbilla Comunidad de Madrid',
#   40.431979,
#   -3.295011),
#  ('villamanrique-de-tajo',
#   'Park',
#   '59bd10284186867189850394',
#   'VeryLikelyOpen',
#   327.0,
#   '/v3/places/59bd10284186867189850394',
#   'Parque Fluvial Villamanrique de Tajo',
#   '28598 Villamanrique de Tajo Comunidad de Madrid',
#   40.065794,
#   -3.239405),
#  ('villanueva-de-la-canada',
#   'Park',
#   '4c8c036a509e37046d862f55',
#   'LikelyOpen',
#   577.0,
#   '/v3/places/4c8c036a509e37046d862f55',
#   "Arevalo's Park",
#   'Arévalo',
#   40.452004,
#   -4.005417),
#  ('villanueva-de-la-canada',
#   'Park',
#   '4d60d40ed7206ea870c9f9f1',
#   'LikelyOpen',
#   739.0,
#   '/v3/places/4d60d40ed7206ea870c9f9f1',
#   'Pinar de la Cañada',
#   'Cañada',
#   40.451747,
#   -3.996396),
#  ('villanueva-de-la-canada',
#   'Park',
#   '4e0cf1a08877936cb3f7187d',
#   'LikelyOpen',
#   789.0,
#   '/v3/places/4e0cf1a08877936cb3f7187d',
#   'El Parque del Verano',
#   '28691 Villanueva de la Cañada Comunidad de Madrid',
#   40.453012,
#   -3.997402),
#  ('villanueva-de-la-canada',
#   'Park',
#   '5c61a3ceb9a5a8002c84be45',
#   'VeryLikelyOpen',
#   803.0,
#   '/v3/places/5c61a3ceb9a5a8002c84be45',
#   'Parque Infantil Avda Metepec',
#   'Avenida Metepec 2B, 28691 Villanueva de la Cañada Comunidad de Madrid',
#   40.445388,
#   -3.993606),
#  ('villanueva-de-la-canada',
#   'Park',
#   '4d5ac6f1f8ff236a08cfd94a',
#   'LikelyOpen',
#   857.0,
#   '/v3/places/4d5ac6f1f8ff236a08cfd94a',
#   'Parque del Heiser',
#   nan,
#   40.452928,
#   -3.995979),
#  ('villanueva-de-la-canada',
#   'Park',
#   '5d7bcc3069a1450008247016',
#   'VeryLikelyOpen',
#   1280.0,
#   '/v3/places/5d7bcc3069a1450008247016',
#   'Parque Infantil',
#   'Avenida De Castilla yLeón, 28691 Villanueva de la Cañada Comunidad de Madrid',
#   40.436487,
#   -3.997247),
#  ('villanueva-de-la-canada',
#   'Monument',
#   '676364908f9a4900fa0812e4',
#   'LikelyOpen',
#   985.0,
#   '/v3/places/676364908f9a4900fa0812e4',
#   'Complejo Deportivo Santiago Apóstol',
#   'Avenida Polideportivo, s/n, 28691 Villanueva de la Cañada Comunidad de Madrid',
#   40.455226,
#   -3.995173),
#  ('villanueva-de-la-canada',
#   'Monument',
#   'ddb3c3e13ed346b308eca5c0',
#   'Unsure',
#   809.0,
#   '/v3/places/ddb3c3e13ed346b308eca5c0',
#   'Centro Deportivo San Isidro',
#   'Villanueva de la Cañada',
#   40.440059,
#   -4.00097),
#  ('villanueva-de-la-canada',
#   'Monument',
#   '44d77b2627c64dc48a278e53',
#   'Unsure',
#   962.0,
#   '/v3/places/44d77b2627c64dc48a278e53',
#   'Piscina Cubierta Municipal',
#   'Villanueva de la Cañada Córdoba',
#   40.454161,
#   -3.996001),
#  ('villanueva-del-pardillo',
#   'Park',
#   '50817da7e4b09e409b84eeab',
#   'LikelyOpen',
#   337.0,
#   '/v3/places/50817da7e4b09e409b84eeab',
#   'Fiestas de Villanueva del Pardillo',
#   nan,
#   40.493946,
#   -3.963791),
#  ('villanueva-del-pardillo',
#   'Park',
#   'cfbe75a61929499e28e0283c',
#   'LikelyOpen',
#   582.0,
#   '/v3/places/cfbe75a61929499e28e0283c',
#   'Ocio Infantil',
#   'Gral. Mola, 13, 28229 Villanueva del Pardillo Comunidad de Madrid',
#   40.490092,
#   -3.963178),
#  ('villanueva-del-pardillo',
#   'Park',
#   '4e5d2e1088771beefa9570aa',
#   'LikelyOpen',
#   596.0,
#   '/v3/places/4e5d2e1088771beefa9570aa',
#   'Parque de al Lado del Rio',
#   'Comunidad de Madrid',
#   40.494181,
#   -3.966993),
#  ('villanueva-del-pardillo',
#   'Park',
#   '4f8162b6e4b0ef20990bae3f',
#   'LikelyOpen',
#   599.0,
#   '/v3/places/4f8162b6e4b0ef20990bae3f',
#   'Parque Antonio Machado',
#   'Villanueva del Pardillo Comunidad de Madrid',
#   40.494118,
#   -3.967019),
#  ('villanueva-del-pardillo',
#   'Park',
#   '4f5cba9ee4b0090c0ab5a08e',
#   'LikelyOpen',
#   695.0,
#   '/v3/places/4f5cba9ee4b0090c0ab5a08e',
#   'Parque del Reloj',
#   'Avda. De Madrid, Villanueva del Pardillo Comunidad de Madrid',
#   40.48885,
#   -3.958019),
#  ('villanueva-del-pardillo',
#   'Park',
#   '5b046b0fb9a5a8002c910638',
#   'LikelyOpen',
#   1339.0,
#   '/v3/places/5b046b0fb9a5a8002c910638',
#   'Parque de la Tirolina',
#   '28229 Villanueva del Pardillo Comunidad de Madrid',
#   40.483016,
#   -3.962455),
#  ('villarejo-de-salvanes',
#   'Park',
#   '502c1d0f83025ae48dff342a',
#   'LikelyOpen',
#   526.0,
#   '/v3/places/502c1d0f83025ae48dff342a',
#   'Parque Infantil',
#   'c/ Viso, 28590 Villarejo de Salvanés Comunidad de Madrid',
#   40.169294,
#   -3.279958),
#  ('villaviciosa-de-odon',
#   'Park',
#   '54e89b5d498e1348dd51f8ba',
#   'LikelyOpen',
#   1747.0,
#   '/v3/places/54e89b5d498e1348dd51f8ba',
#   'Mi Mundo',
#   'Avenida de las Nieves, 35, 28935 Móstoles Comunidad de Madrid',
#   40.350023,
#   -3.881915),
#  ('villaviciosa-de-odon',
#   'Park',
#   '4fed68bde4b0f5b9d76b4fa2',
#   'LikelyOpen',
#   350.0,
#   '/v3/places/4fed68bde4b0f5b9d76b4fa2',
#   'Parque de las Margaritas',
#   nan,
#   40.356448,
#   -3.904184),
#  ('villaviciosa-de-odon',
#   'Park',
#   '4fcb4a74e4b0a6e7151b91e1',
#   'LikelyOpen',
#   422.0,
#   '/v3/places/4fcb4a74e4b0a6e7151b91e1',
#   'Pinar del Castillo',
#   'Pinar',
#   40.358165,
#   -3.89535),
#  ('villaviciosa-de-odon',
#   'Park',
#   '503ba9e4e4b0105c0f87dbfc',
#   'LikelyOpen',
#   710.0,
#   '/v3/places/503ba9e4e4b0105c0f87dbfc',
#   'Parque Vicente Ferrer',
#   nan,
#   40.358766,
#   -3.908421),
#  ('villaviciosa-de-odon',
#   'Park',
#   '4eb9ce72f5b9ea8ad72b8677',
#   'LikelyOpen',
#   792.0,
#   '/v3/places/4eb9ce72f5b9ea8ad72b8677',
#   'Parque Antonio Machado',
#   '28670 Villaviciosa de Odón Comunidad de Madrid',
#   40.354856,
#   -3.908984),
#  ('villaviciosa-de-odon',
#   'Park',
#   '4f8c367de4b0af4d5076f36f',
#   'LikelyOpen',
#   836.0,
#   '/v3/places/4f8c367de4b0af4d5076f36f',
#   'Parque Vaillo',
#   'Villaviciosa de Odón Comunidad de Madrid',
#   40.361322,
#   -3.908654),
#  ('villaviciosa-de-odon',
#   'Park',
#   '51ffcb685019c1bb402374fd',
#   'LikelyOpen',
#   1043.0,
#   '/v3/places/51ffcb685019c1bb402374fd',
#   'Matadero de Villaviciosa CQB ARISOFT',
#   '28670 Villaviciosa de Odón Comunidad de Madrid',
#   40.351365,
#   -3.890769),
#  ('villaviciosa-de-odon',
#   'Park',
#   '4c7a6f88566db60c43e7470e',
#   'LikelyOpen',
#   1626.0,
#   '/v3/places/4c7a6f88566db60c43e7470e',
#   'Parque del Castillo',
#   'Avenida del Castillo, 28670 Villaviciosa de Odón Comunidad de Madrid',
#   40.357793,
#   -3.881113),
#  ('villaviciosa-de-odon',
#   'Monument',
#   '5834bfa364f54721bc08814d',
#   'Unsure',
#   747.0,
#   '/v3/places/5834bfa364f54721bc08814d',
#   'Discoteca Doblón',
#   'Avenida Principe de Asturias, 94, Villaviciosa de Odón Madrid',
#   40.360011,
#   -3.90836),
#  ('zarzalejo',
#   'Park',
#   '4ed124af5c5c9528fa2230de',
#   'LikelyOpen',
#   1577.0,
#   '/v3/places/4ed124af5c5c9528fa2230de',
#   'Pinar Zarzalejo',
#   'Pinar',
#   40.540691,
#   -4.165816),
#  ('zarzalejo',
#   'Park',
#   '533ff52e498edb19c2e9aff6',
#   'LikelyOpen',
#   1803.0,
#   '/v3/places/533ff52e498edb19c2e9aff6',
#   'Parque Pedro Rodríguez-Ponga',
#   'Avenida de la Estación, 45, Zarzalejo Comunidad de Madrid',
#   40.539747,
#   -4.163441)]

# %%
df_api['category'].unique()
# Out:
# array(['Park', 'Monument', 'TV Station', 'Castle', 'Film Studio',
#        'Palace', 'Fountain', 'Bridge', 'Beach',
#        'Print, TV, Radio and Outdoor Advertising Service'], dtype=object)

# %%
df_api.head()
# Out:
#   municipio category                    fsq_id   closed_bucket  distance  \
# 0   ajalvir     Park  4d3c6c5b84d46ea87dddfd5c      LikelyOpen     563.0
# 1   ajalvir     Park  4f54f7bfe4b036244d02685b  VeryLikelyOpen    1724.0
# 2   ajalvir     Park  7d4ef99ca2dd4789f032a90c      LikelyOpen     333.0
# 3  alamo-el     Park  53de1144498e8fd8d8cb3537      LikelyOpen     118.0
# 4  alamo-el     Park  51a8f451498ecb8334de37df      LikelyOpen     582.0
#
#                                   link              name  \
# 0  /v3/places/4d3c6c5b84d46ea87dddfd5c       Diverjungla
# 1  /v3/places/4f54f7bfe4b036244d02685b   Parque Infantil
# 2  /v3/places/7d4ef99ca2dd4789f032a90c         Chiquitin
# 3  /v3/places/53de1144498e8fd8d8cb3537      Isla Perejil
# 4  /v3/places/51a8f451498ecb8334de37df  Parque de Madera
#
#                                              address   latitude  longitude
# 0  Calle Segovia, 20 (Pol. Ind. Donada), 28864 Aj...  40.529921  -3.484341
# 1                                                NaN  40.543867  -3.464773
# 2                                     Ajalvir Madrid  40.531662  -3.482835
# 3                 28607 El Alamo Comunidad de Madrid  40.230993  -3.991942
# 4                                                NaN  40.234636  -3.995166

# %%
df_aemet.head()
# Out:
#                            cielo  temp._(°c)  sen._térmica_(°c)  \
# fecha
# 2024-08-29 12:00:00  Nubes altas          21                 21
# 2024-08-29 13:00:00  Nubes altas          24                 24
# 2024-08-29 14:00:00   Muy nuboso          23                 23
# 2024-08-29 15:00:00  Nubes altas          23                 23
# 2024-08-29 16:00:00  Nubes altas          21                 21
#
#                      racha_máx._(km/h)  precipitación_(mm)  nieve_(mm)  \
# fecha
# 2024-08-29 12:00:00               25.0                 0.0           0
# 2024-08-29 13:00:00               29.0                 0.0           0
# 2024-08-29 14:00:00               33.0                 0.0           0
# 2024-08-29 15:00:00               35.0                 0.0           0
# 2024-08-29 16:00:00               34.0                 0.0           0
#
#                      humedad_relativa_(%) prob._precip.__(%)  \
# fecha
# 2024-08-29 12:00:00                    69                 95
# 2024-08-29 13:00:00                    57             Riesgo
# 2024-08-29 14:00:00                    59                100
# 2024-08-29 15:00:00                    55             Riesgo
# 2024-08-29 16:00:00                    65             Riesgo
#
#                      prob._de_nieve_(%)  prob._de_tormenta_(%)  avisos  \
# fecha
# 2024-08-29 12:00:00                   0                     75  Riesgo
# 2024-08-29 13:00:00                   0                     75  Riesgo
# 2024-08-29 14:00:00                   0                     80  Riesgo
# 2024-08-29 15:00:00                   0                     80  Riesgo
# 2024-08-29 16:00:00                   0                     80  Riesgo
#
#                     dirección_viento  velocidad_del_viento     localizacion_id
# fecha
# 2024-08-29 12:00:00                S                     7  acebeda-la-id28001
# 2024-08-29 13:00:00               SE                    12  acebeda-la-id28001
# 2024-08-29 14:00:00                S                    14  acebeda-la-id28001
# 2024-08-29 15:00:00                S                    17  acebeda-la-id28001
# 2024-08-29 16:00:00                S                    20  acebeda-la-id28001

# %%
df_aemet.columns
# Out:
# Index(['cielo', 'temp._(°c)', 'sen._térmica_(°c)', 'racha_máx._(km/h)',
#        'precipitación_(mm)', 'nieve_(mm)', 'humedad_relativa_(%)',
#        'prob._precip.__(%)', 'prob._de_nieve_(%)', 'prob._de_tormenta_(%)',
#        'avisos', 'dirección_viento', 'velocidad_del_viento', 'localizacion_id',
#        'nombre', 'id'],
#       dtype='object')

# %%
df_aemet.shape
# Out:
# (7885, 14)

# %%
df_aemet.nunique()
# Out:
# cielo                     23
# temp._(°c)                24
# sen._térmica_(°c)         26
# racha_máx._(km/h)         70
# precipitación_(mm)        29
# nieve_(mm)                 1
# humedad_relativa_(%)      67
# prob._precip.__(%)        22
# prob._de_nieve_(%)         1
# prob._de_tormenta_(%)     19
# avisos                     2
# dirección_viento           9
# velocidad_del_viento      43
# localizacion_id          179
# dtype: int64

# %%
df_aemet[['nombre', 'id']] = df_aemet['localizacion_id'].str.rsplit('-', n=1, expand=True)
# quiero quedarme con el nombre y el id

# %%
df_aemet.head()
# Out:
#                            cielo  temp._(°c)  sen._térmica_(°c)  \
# fecha
# 2024-08-29 12:00:00  Nubes altas          21                 21
# 2024-08-29 13:00:00  Nubes altas          24                 24
# 2024-08-29 14:00:00   Muy nuboso          23                 23
# 2024-08-29 15:00:00  Nubes altas          23                 23
# 2024-08-29 16:00:00  Nubes altas          21                 21
#
#                      racha_máx._(km/h)  precipitación_(mm)  nieve_(mm)  \
# fecha
# 2024-08-29 12:00:00               25.0                 0.0           0
# 2024-08-29 13:00:00               29.0                 0.0           0
# 2024-08-29 14:00:00               33.0                 0.0           0
# 2024-08-29 15:00:00               35.0                 0.0           0
# 2024-08-29 16:00:00               34.0                 0.0           0
#
#                      humedad_relativa_(%) prob._precip.__(%)  \
# fecha
# 2024-08-29 12:00:00                    69                 95
# 2024-08-29 13:00:00                    57             Riesgo
# 2024-08-29 14:00:00                    59                100
# 2024-08-29 15:00:00                    55             Riesgo
# 2024-08-29 16:00:00                    65             Riesgo
#
#                      prob._de_nieve_(%)  prob._de_tormenta_(%)  avisos  \
# fecha
# 2024-08-29 12:00:00                   0                     75  Riesgo
# 2024-08-29 13:00:00                   0                     75  Riesgo
# 2024-08-29 14:00:00                   0                     80  Riesgo
# 2024-08-29 15:00:00                   0                     80  Riesgo
# 2024-08-29 16:00:00                   0                     80  Riesgo
#
#                     dirección_viento  velocidad_del_viento  \
# fecha
# 2024-08-29 12:00:00                S                     7
# 2024-08-29 13:00:00               SE                    12
# 2024-08-29 14:00:00                S                    14
# 2024-08-29 15:00:00                S                    17
# 2024-08-29 16:00:00                S                    20
#
#                         localizacion_id      nombre       id
# fecha
# 2024-08-29 12:00:00  acebeda-la-id28001  acebeda-la  id28001
# 2024-08-29 13:00:00  acebeda-la-id28001  acebeda-la  id28001
# 2024-08-29 14:00:00  acebeda-la-id28001  acebeda-la  id28001
# 2024-08-29 15:00:00  acebeda-la-id28001  acebeda-la  id28001
# 2024-08-29 16:00:00  acebeda-la-id28001  acebeda-la  id28001

# %%
df_aemet['avisos'].unique()
# Out:
# array(['Riesgo', 'Sin riesgo'], dtype=object)

# %%
lista_aemet = []
for fila in df_aemet.values:
    lista_aemet.append(tuple(fila))

lista_aemet
# Out:
# [('Nubes altas',
#   21,
#   21,
#   25.0,
#   0.0,
#   0,
#   69,
#   '95',
#   0,
#   75,
#   'Riesgo',
#   'S',
#   7,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nubes altas',
#   24,
#   24,
#   29.0,
#   0.0,
#   0,
#   57,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'SE',
#   12,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Muy nuboso',
#   23,
#   23,
#   33.0,
#   0.0,
#   0,
#   59,
#   '100',
#   0,
#   80,
#   'Riesgo',
#   'S',
#   14,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nubes altas',
#   23,
#   23,
#   35.0,
#   0.0,
#   0,
#   55,
#   'Riesgo',
#   0,
#   80,
#   'Riesgo',
#   'S',
#   17,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nubes altas',
#   21,
#   21,
#   34.0,
#   0.0,
#   0,
#   65,
#   'Riesgo',
#   0,
#   80,
#   'Riesgo',
#   'S',
#   20,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Cubierto con tormenta y lluvia escasa',
#   21,
#   21,
#   35.0,
#   0.1,
#   0,
#   59,
#   'Riesgo',
#   0,
#   80,
#   'Riesgo',
#   'S',
#   17,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nuboso',
#   20,
#   20,
#   19.0,
#   0.0,
#   0,
#   65,
#   'Riesgo',
#   0,
#   80,
#   'Riesgo',
#   'S',
#   20,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nuboso',
#   19,
#   19,
#   27.0,
#   0.0,
#   0,
#   60,
#   'Riesgo',
#   0,
#   80,
#   'Riesgo',
#   'S',
#   9,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nuboso',
#   19,
#   19,
#   7.0,
#   0.0,
#   0,
#   46,
#   '65',
#   0,
#   45,
#   'Riesgo',
#   'S',
#   11,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nubes altas',
#   18,
#   18,
#   9.0,
#   0.0,
#   0,
#   52,
#   'Riesgo',
#   0,
#   45,
#   'Riesgo',
#   'NE',
#   4,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nubes altas',
#   17,
#   17,
#   10.0,
#   0.0,
#   0,
#   58,
#   'Riesgo',
#   0,
#   45,
#   'Riesgo',
#   'NO',
#   5,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Cielo despejado',
#   16,
#   16,
#   9.0,
#   0.0,
#   0,
#   65,
#   'Riesgo',
#   0,
#   45,
#   'Riesgo',
#   'NO',
#   7,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Poco nuboso',
#   15,
#   15,
#   6.0,
#   0.0,
#   0,
#   70,
#   'Riesgo',
#   0,
#   45,
#   'Sin riesgo',
#   'NO',
#   4,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Intervalos nubosos con lluvia escasa',
#   15,
#   15,
#   13.0,
#   0.1,
#   0,
#   75,
#   'Riesgo',
#   0,
#   45,
#   'Sin riesgo',
#   'S',
#   4,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nubes altas',
#   14,
#   14,
#   13.0,
#   0.0,
#   0,
#   90,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'N',
#   6,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Cielo despejado',
#   14,
#   14,
#   13.0,
#   0.0,
#   0,
#   100,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'N',
#   8,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Poco nuboso',
#   14,
#   14,
#   9.0,
#   0.0,
#   0,
#   100,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'N',
#   8,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Cubierto',
#   13,
#   13,
#   6.0,
#   0.0,
#   0,
#   100,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'N',
#   5,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Cubierto',
#   13,
#   13,
#   6.0,
#   0.0,
#   0,
#   100,
#   'Riesgo',
#   0,
#   15,
#   'Sin riesgo',
#   'N',
#   4,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Muy nuboso',
#   13,
#   13,
#   6.0,
#   0.0,
#   0,
#   100,
#   'Riesgo',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   4,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Poco nuboso',
#   12,
#   12,
#   8.0,
#   0.0,
#   0,
#   100,
#   '80',
#   0,
#   70,
#   'Riesgo',
#   'N',
#   2,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Poco nuboso',
#   15,
#   15,
#   17.0,
#   0.0,
#   0,
#   100,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'NO',
#   5,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Cubierto',
#   17,
#   17,
#   22.0,
#   0.0,
#   0,
#   90,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'SE',
#   7,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Cubierto con lluvia escasa',
#   19,
#   19,
#   35.0,
#   1.0,
#   0,
#   77,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'S',
#   11,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Cubierto con lluvia',
#   21,
#   21,
#   30.0,
#   20.0,
#   0,
#   74,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'SE',
#   16,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Cubierto con lluvia',
#   23,
#   23,
#   14.0,
#   3.0,
#   0,
#   59,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'E',
#   10,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Intervalos nubosos con lluvia escasa',
#   24,
#   24,
#   15.0,
#   0.1,
#   0,
#   47,
#   '80',
#   0,
#   70,
#   'Riesgo',
#   'NO',
#   9,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nubes altas',
#   25,
#   25,
#   16.0,
#   0.0,
#   0,
#   44,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'SO',
#   7,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nubes altas',
#   25,
#   25,
#   11.0,
#   0.0,
#   0,
#   50,
#   'Riesgo',
#   0,
#   70,
#   'Sin riesgo',
#   'SE',
#   8,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Poco nuboso',
#   26,
#   26,
#   13.0,
#   0.0,
#   0,
#   47,
#   'Riesgo',
#   0,
#   70,
#   'Sin riesgo',
#   'S',
#   5,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Poco nuboso',
#   25,
#   25,
#   18.0,
#   0.0,
#   0,
#   49,
#   'Riesgo',
#   0,
#   70,
#   'Sin riesgo',
#   'SE',
#   6,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nubes altas',
#   24,
#   24,
#   12.0,
#   0.0,
#   0,
#   48,
#   'Riesgo',
#   0,
#   70,
#   'Sin riesgo',
#   'S',
#   10,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nuboso',
#   24,
#   24,
#   5.0,
#   0.0,
#   0,
#   58,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'S',
#   6,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Poco nuboso',
#   21,
#   21,
#   5.0,
#   0.0,
#   0,
#   69,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'NO',
#   3,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Poco nuboso',
#   19,
#   19,
#   6.0,
#   0.0,
#   0,
#   77,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'NO',
#   3,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Poco nuboso',
#   16,
#   16,
#   6.0,
#   0.0,
#   0,
#   88,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'N',
#   4,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Muy nuboso',
#   16,
#   16,
#   5.0,
#   0.0,
#   0,
#   88,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'O',
#   3,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nuboso',
#   16,
#   16,
#   7.0,
#   0.0,
#   0,
#   92,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'O',
#   2,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Cielo despejado',
#   16,
#   16,
#   3.0,
#   0.0,
#   0,
#   96,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'SO',
#   3,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nuboso',
#   15,
#   15,
#   5.0,
#   0.0,
#   0,
#   96,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'C',
#   0,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Poco nuboso',
#   14,
#   14,
#   3.0,
#   0.0,
#   0,
#   98,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'E',
#   3,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Poco nuboso',
#   14,
#   14,
#   9.0,
#   0.0,
#   0,
#   97,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'NO',
#   1,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nuboso',
#   14,
#   14,
#   13.0,
#   0.0,
#   0,
#   93,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'NO',
#   6,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Nubes altas',
#   13,
#   13,
#   10.0,
#   0.0,
#   0,
#   97,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'NO',
#   7,
#   'acebeda-la-id28001',
#   'acebeda-la',
#   'id28001'),
#  ('Cubierto con tormenta y lluvia escasa',
#   24,
#   24,
#   15.0,
#   0.1,
#   0,
#   64,
#   '95',
#   0,
#   70,
#   'Riesgo',
#   'E',
#   8,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Cubierto con tormenta y lluvia escasa',
#   26,
#   26,
#   18.0,
#   0.1,
#   0,
#   57,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'E',
#   7,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Nubes altas',
#   27,
#   27,
#   18.0,
#   0.0,
#   0,
#   51,
#   '100',
#   0,
#   75,
#   'Riesgo',
#   'E',
#   8,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Muy nuboso',
#   28,
#   28,
#   21.0,
#   0.0,
#   0,
#   44,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'S',
#   7,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Nubes altas',
#   27,
#   27,
#   40.0,
#   0.0,
#   0,
#   46,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'SO',
#   11,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Cubierto',
#   25,
#   25,
#   14.0,
#   0.0,
#   0,
#   49,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'S',
#   25,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Cubierto con tormenta y lluvia escasa',
#   26,
#   26,
#   65.0,
#   0.1,
#   0,
#   49,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'SO',
#   4,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Muy nuboso con tormenta y lluvia escasa',
#   24,
#   24,
#   18.0,
#   0.3,
#   0,
#   48,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'O',
#   41,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Nubes altas',
#   22,
#   22,
#   18.0,
#   0.0,
#   0,
#   54,
#   '80',
#   0,
#   65,
#   'Riesgo',
#   'NE',
#   13,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Nubes altas',
#   21,
#   21,
#   23.0,
#   0.0,
#   0,
#   68,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'NE',
#   11,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Cubierto con lluvia escasa',
#   20,
#   20,
#   17.0,
#   1.0,
#   0,
#   85,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'E',
#   9,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Muy nuboso con lluvia',
#   20,
#   20,
#   24.0,
#   7.0,
#   0,
#   92,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'E',
#   5,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Intervalos nubosos con lluvia escasa',
#   19,
#   19,
#   15.0,
#   0.8,
#   0,
#   86,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'N',
#   17,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Cielo despejado',
#   19,
#   19,
#   18.0,
#   0.0,
#   0,
#   93,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'E',
#   9,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Intervalos nubosos',
#   19,
#   19,
#   31.0,
#   0.0,
#   0,
#   96,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'N',
#   12,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Intervalos nubosos',
#   18,
#   18,
#   26.0,
#   0.0,
#   0,
#   96,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'NE',
#   21,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Intervalos nubosos',
#   18,
#   18,
#   21.0,
#   0.0,
#   0,
#   98,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'N',
#   16,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Intervalos nubosos',
#   18,
#   18,
#   23.0,
#   0.0,
#   0,
#   100,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'NE',
#   14,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Intervalos nubosos',
#   18,
#   18,
#   30.0,
#   0.0,
#   0,
#   100,
#   'Riesgo',
#   0,
#   20,
#   'Sin riesgo',
#   'NE',
#   16,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Intervalos nubosos',
#   17,
#   17,
#   15.0,
#   0.0,
#   0,
#   100,
#   'Riesgo',
#   0,
#   20,
#   'Sin riesgo',
#   'NE',
#   18,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Muy nuboso',
#   17,
#   17,
#   26.0,
#   0.0,
#   0,
#   100,
#   '25',
#   0,
#   25,
#   'Riesgo',
#   'N',
#   11,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Muy nuboso',
#   19,
#   19,
#   22.0,
#   0.0,
#   0,
#   96,
#   'Riesgo',
#   0,
#   25,
#   'Riesgo',
#   'NE',
#   17,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Cubierto',
#   22,
#   22,
#   26.0,
#   0.0,
#   0,
#   86,
#   'Riesgo',
#   0,
#   25,
#   'Riesgo',
#   'E',
#   13,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Cubierto',
#   24,
#   24,
#   27.0,
#   0.0,
#   0,
#   78,
#   'Riesgo',
#   0,
#   25,
#   'Riesgo',
#   'SE',
#   18,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Muy nuboso',
#   25,
#   25,
#   28.0,
#   0.0,
#   0,
#   55,
#   'Riesgo',
#   0,
#   25,
#   'Riesgo',
#   'NE',
#   6,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Nubes altas',
#   26,
#   26,
#   36.0,
#   0.0,
#   0,
#   53,
#   'Riesgo',
#   0,
#   25,
#   'Riesgo',
#   'N',
#   14,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Cubierto con lluvia escasa',
#   28,
#   29,
#   24.0,
#   0.1,
#   0,
#   51,
#   '50',
#   0,
#   50,
#   'Riesgo',
#   'N',
#   19,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Cubierto con lluvia escasa',
#   28,
#   29,
#   19.0,
#   0.1,
#   0,
#   52,
#   'Riesgo',
#   0,
#   50,
#   'Riesgo',
#   'NE',
#   14,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Intervalos nubosos con lluvia escasa',
#   29,
#   29,
#   18.0,
#   0.1,
#   0,
#   48,
#   'Riesgo',
#   0,
#   50,
#   'Sin riesgo',
#   'NE',
#   10,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Cubierto con lluvia escasa',
#   30,
#   31,
#   15.0,
#   0.1,
#   0,
#   52,
#   'Riesgo',
#   0,
#   50,
#   'Sin riesgo',
#   'NE',
#   10,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Intervalos nubosos con lluvia escasa',
#   27,
#   28,
#   16.0,
#   0.1,
#   0,
#   62,
#   'Riesgo',
#   0,
#   50,
#   'Sin riesgo',
#   'NE',
#   9,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Intervalos nubosos con lluvia escasa',
#   23,
#   23,
#   16.0,
#   0.1,
#   0,
#   73,
#   'Riesgo',
#   0,
#   50,
#   'Sin riesgo',
#   'NE',
#   11,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Nubes altas',
#   24,
#   24,
#   11.0,
#   0.0,
#   0,
#   84,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NE',
#   10,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Nubes altas',
#   23,
#   23,
#   14.0,
#   0.0,
#   0,
#   88,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NE',
#   8,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Poco nuboso',
#   22,
#   22,
#   15.0,
#   0.0,
#   0,
#   90,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'N',
#   9,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Cubierto',
#   21,
#   21,
#   13.0,
#   0.0,
#   0,
#   91,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NE',
#   10,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Muy nuboso',
#   20,
#   20,
#   9.0,
#   0.0,
#   0,
#   88,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NE',
#   9,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Muy nuboso',
#   20,
#   20,
#   10.0,
#   0.0,
#   0,
#   90,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NE',
#   7,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Cubierto',
#   20,
#   20,
#   9.0,
#   0.0,
#   0,
#   91,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   6,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Poco nuboso',
#   19,
#   19,
#   13.0,
#   0.0,
#   0,
#   93,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'E',
#   6,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Cielo despejado',
#   18,
#   18,
#   18.0,
#   0.0,
#   0,
#   92,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   9,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Cielo despejado',
#   18,
#   18,
#   18.0,
#   0.0,
#   0,
#   96,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'N',
#   13,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Cielo despejado',
#   17,
#   17,
#   9.0,
#   0.0,
#   0,
#   94,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'N',
#   11,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Nubes altas',
#   17,
#   17,
#   10.0,
#   0.0,
#   0,
#   95,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   7,
#   'ajalvir-id28002',
#   'ajalvir',
#   'id28002'),
#  ('Muy nuboso',
#   23,
#   23,
#   23.0,
#   0.0,
#   0,
#   64,
#   '90',
#   0,
#   75,
#   'Riesgo',
#   'E',
#   6,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Nubes altas',
#   26,
#   26,
#   28.0,
#   0.0,
#   0,
#   50,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'E',
#   8,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Nubes altas',
#   25,
#   25,
#   35.0,
#   0.0,
#   0,
#   50,
#   '100',
#   0,
#   75,
#   'Riesgo',
#   'S',
#   12,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Nubes altas',
#   24,
#   24,
#   35.0,
#   0.0,
#   0,
#   54,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'S',
#   15,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   25,
#   25,
#   32.0,
#   0.0,
#   0,
#   48,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'S',
#   17,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Muy nuboso con tormenta y lluvia escasa',
#   25,
#   25,
#   32.0,
#   0.1,
#   0,
#   50,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'S',
#   13,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Cubierto',
#   22,
#   22,
#   37.0,
#   0.0,
#   0,
#   54,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'S',
#   15,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Nubes altas',
#   19,
#   19,
#   14.0,
#   0.0,
#   0,
#   70,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'S',
#   18,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   20,
#   20,
#   12.0,
#   0.0,
#   0,
#   43,
#   '60',
#   0,
#   50,
#   'Riesgo',
#   'O',
#   6,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Intervalos nubosos con lluvia escasa',
#   18,
#   18,
#   10.0,
#   0.1,
#   0,
#   56,
#   'Riesgo',
#   0,
#   50,
#   'Riesgo',
#   'NO',
#   6,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   16,
#   16,
#   11.0,
#   0.0,
#   0,
#   63,
#   'Riesgo',
#   0,
#   50,
#   'Riesgo',
#   'N',
#   4,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Cielo despejado',
#   15,
#   15,
#   7.0,
#   0.0,
#   0,
#   69,
#   'Riesgo',
#   0,
#   50,
#   'Riesgo',
#   'NO',
#   6,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Cielo despejado',
#   13,
#   13,
#   14.0,
#   0.0,
#   0,
#   75,
#   'Riesgo',
#   0,
#   50,
#   'Sin riesgo',
#   'NO',
#   3,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Cielo despejado',
#   12,
#   12,
#   12.0,
#   0.0,
#   0,
#   78,
#   'Riesgo',
#   0,
#   50,
#   'Sin riesgo',
#   'E',
#   7,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   13,
#   13,
#   15.0,
#   0.0,
#   0,
#   88,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'NO',
#   3,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   12,
#   12,
#   13.0,
#   0.0,
#   0,
#   89,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'NO',
#   8,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   12,
#   12,
#   11.0,
#   0.0,
#   0,
#   93,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'NO',
#   7,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   12,
#   12,
#   9.0,
#   0.0,
#   0,
#   95,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'NO',
#   6,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   12,
#   12,
#   8.0,
#   0.0,
#   0,
#   95,
#   'Riesgo',
#   0,
#   20,
#   'Sin riesgo',
#   'NO',
#   5,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Muy nuboso',
#   12,
#   12,
#   8.0,
#   0.0,
#   0,
#   95,
#   'Riesgo',
#   0,
#   20,
#   'Sin riesgo',
#   'NO',
#   4,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Cielo despejado',
#   11,
#   11,
#   8.0,
#   0.0,
#   0,
#   100,
#   '90',
#   0,
#   65,
#   'Riesgo',
#   'NO',
#   4,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Cielo despejado',
#   15,
#   15,
#   14.0,
#   0.0,
#   0,
#   93,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'O',
#   3,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Cubierto',
#   18,
#   18,
#   23.0,
#   0.0,
#   0,
#   77,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'SE',
#   5,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Cubierto con lluvia',
#   21,
#   21,
#   25.0,
#   9.0,
#   0,
#   71,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'E',
#   10,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Cubierto con lluvia',
#   23,
#   23,
#   29.0,
#   5.0,
#   0,
#   71,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'SE',
#   9,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Cubierto con lluvia',
#   25,
#   25,
#   23.0,
#   3.0,
#   0,
#   54,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'S',
#   12,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Intervalos nubosos con lluvia escasa',
#   27,
#   27,
#   8.0,
#   0.2,
#   0,
#   42,
#   '80',
#   0,
#   65,
#   'Riesgo',
#   'N',
#   11,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Muy nuboso',
#   27,
#   27,
#   15.0,
#   0.0,
#   0,
#   45,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'S',
#   3,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Nubes altas',
#   27,
#   27,
#   15.0,
#   0.0,
#   0,
#   44,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'SE',
#   6,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Nubes altas',
#   28,
#   28,
#   20.0,
#   0.0,
#   0,
#   41,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'E',
#   5,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   26,
#   26,
#   16.0,
#   0.0,
#   0,
#   39,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'SE',
#   8,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   25,
#   25,
#   11.0,
#   0.0,
#   0,
#   43,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'E',
#   7,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   24,
#   24,
#   12.0,
#   0.0,
#   0,
#   48,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'E',
#   3,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   21,
#   21,
#   9.0,
#   0.0,
#   0,
#   55,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NO',
#   7,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   19,
#   19,
#   11.0,
#   0.0,
#   0,
#   67,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NO',
#   5,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Nuboso',
#   16,
#   16,
#   10.0,
#   0.0,
#   0,
#   77,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NO',
#   6,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Cubierto',
#   15,
#   15,
#   9.0,
#   0.0,
#   0,
#   81,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NO',
#   6,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   14,
#   14,
#   15.0,
#   0.0,
#   0,
#   85,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NO',
#   4,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   13,
#   13,
#   10.0,
#   0.0,
#   0,
#   93,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'N',
#   7,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   12,
#   12,
#   11.0,
#   0.0,
#   0,
#   90,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'N',
#   5,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   11,
#   11,
#   11.0,
#   0.0,
#   0,
#   93,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'N',
#   6,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Cielo despejado',
#   12,
#   12,
#   14.0,
#   0.0,
#   0,
#   91,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'N',
#   5,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Poco nuboso',
#   12,
#   12,
#   13.0,
#   0.0,
#   0,
#   89,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'NO',
#   7,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Nubes altas',
#   12,
#   12,
#   10.0,
#   0.0,
#   0,
#   86,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'O',
#   7,
#   'alameda-del-valle-id28003',
#   'alameda-del-valle',
#   'id28003'),
#  ('Cubierto con lluvia escasa',
#   25,
#   25,
#   16.0,
#   0.1,
#   0,
#   55,
#   '65',
#   0,
#   60,
#   'Riesgo',
#   'E',
#   8,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Intervalos nubosos con lluvia escasa',
#   27,
#   27,
#   16.0,
#   0.1,
#   0,
#   48,
#   'Riesgo',
#   0,
#   60,
#   'Riesgo',
#   'E',
#   6,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nubes altas',
#   28,
#   28,
#   18.0,
#   0.0,
#   0,
#   42,
#   '85',
#   0,
#   70,
#   'Riesgo',
#   'S',
#   7,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Cubierto',
#   28,
#   28,
#   22.0,
#   0.0,
#   0,
#   40,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'S',
#   7,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nubes altas',
#   29,
#   29,
#   39.0,
#   0.0,
#   0,
#   37,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'S',
#   11,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Cubierto con lluvia escasa',
#   29,
#   29,
#   58.0,
#   1.0,
#   0,
#   38,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'SE',
#   17,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Intervalos nubosos con lluvia escasa',
#   27,
#   29,
#   25.0,
#   0.4,
#   0,
#   67,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'NO',
#   20,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Muy nuboso',
#   25,
#   25,
#   17.0,
#   0.0,
#   0,
#   72,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'E',
#   17,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Intervalos nubosos con lluvia escasa',
#   23,
#   23,
#   15.0,
#   0.1,
#   0,
#   87,
#   '55',
#   0,
#   55,
#   'Riesgo',
#   'N',
#   12,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Poco nuboso',
#   21,
#   21,
#   19.0,
#   0.0,
#   0,
#   88,
#   'Riesgo',
#   0,
#   55,
#   'Riesgo',
#   'N',
#   9,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Poco nuboso',
#   19,
#   19,
#   22.0,
#   0.0,
#   0,
#   99,
#   'Riesgo',
#   0,
#   55,
#   'Riesgo',
#   'NE',
#   13,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Muy nuboso con lluvia escasa',
#   19,
#   19,
#   19.0,
#   0.1,
#   0,
#   82,
#   'Riesgo',
#   0,
#   55,
#   'Riesgo',
#   'NE',
#   14,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Muy nuboso',
#   19,
#   19,
#   17.0,
#   0.0,
#   0,
#   86,
#   'Riesgo',
#   0,
#   55,
#   'Sin riesgo',
#   'NE',
#   12,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Poco nuboso',
#   19,
#   19,
#   19.0,
#   0.0,
#   0,
#   93,
#   'Riesgo',
#   0,
#   55,
#   'Sin riesgo',
#   'N',
#   12,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nubes altas',
#   18,
#   18,
#   21.0,
#   0.0,
#   0,
#   94,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'NE',
#   13,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Cubierto',
#   18,
#   18,
#   24.0,
#   0.0,
#   0,
#   94,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'NE',
#   15,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Muy nuboso',
#   18,
#   18,
#   26.0,
#   0.0,
#   0,
#   90,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'NE',
#   17,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Cielo despejado',
#   18,
#   18,
#   26.0,
#   0.0,
#   0,
#   92,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'NE',
#   18,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Muy nuboso',
#   18,
#   18,
#   23.0,
#   0.0,
#   0,
#   94,
#   'Riesgo',
#   0,
#   0,
#   'Sin riesgo',
#   'NE',
#   18,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nuboso',
#   18,
#   18,
#   24.0,
#   0.0,
#   0,
#   95,
#   'Riesgo',
#   0,
#   0,
#   'Sin riesgo',
#   'NE',
#   16,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Muy nuboso',
#   18,
#   18,
#   22.0,
#   0.0,
#   0,
#   97,
#   '10',
#   0,
#   10,
#   'Riesgo',
#   'NE',
#   17,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Cubierto',
#   20,
#   20,
#   27.0,
#   0.0,
#   0,
#   90,
#   'Riesgo',
#   0,
#   10,
#   'Riesgo',
#   'NE',
#   14,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Cubierto',
#   22,
#   22,
#   32.0,
#   0.0,
#   0,
#   81,
#   'Riesgo',
#   0,
#   10,
#   'Riesgo',
#   'E',
#   18,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Muy nuboso',
#   24,
#   24,
#   33.0,
#   0.0,
#   0,
#   78,
#   'Riesgo',
#   0,
#   10,
#   'Riesgo',
#   'SE',
#   22,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nubes altas',
#   25,
#   25,
#   26.0,
#   0.0,
#   0,
#   64,
#   'Riesgo',
#   0,
#   10,
#   'Riesgo',
#   'E',
#   17,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nubes altas',
#   27,
#   28,
#   28.0,
#   0.0,
#   0,
#   63,
#   'Riesgo',
#   0,
#   10,
#   'Riesgo',
#   'NE',
#   18,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nuboso',
#   28,
#   29,
#   36.0,
#   0.0,
#   0,
#   57,
#   '45',
#   0,
#   45,
#   'Riesgo',
#   'NE',
#   16,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nuboso',
#   29,
#   30,
#   32.0,
#   0.0,
#   0,
#   56,
#   'Riesgo',
#   0,
#   45,
#   'Riesgo',
#   'NE',
#   24,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nuboso',
#   30,
#   31,
#   24.0,
#   0.0,
#   0,
#   50,
#   'Riesgo',
#   0,
#   45,
#   'Sin riesgo',
#   'NE',
#   20,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Poco nuboso',
#   31,
#   32,
#   21.0,
#   0.0,
#   0,
#   49,
#   'Riesgo',
#   0,
#   45,
#   'Sin riesgo',
#   'NE',
#   16,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Cielo despejado',
#   30,
#   32,
#   17.0,
#   0.0,
#   0,
#   56,
#   'Riesgo',
#   0,
#   45,
#   'Sin riesgo',
#   'NE',
#   14,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nubes altas',
#   29,
#   31,
#   17.0,
#   0.0,
#   0,
#   62,
#   'Riesgo',
#   0,
#   45,
#   'Sin riesgo',
#   'NE',
#   10,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nuboso',
#   28,
#   30,
#   15.0,
#   0.0,
#   0,
#   67,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   12,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nubes altas',
#   26,
#   26,
#   20.0,
#   0.0,
#   0,
#   73,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   11,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nubes altas',
#   24,
#   24,
#   15.0,
#   0.0,
#   0,
#   80,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   14,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Poco nuboso',
#   21,
#   21,
#   14.0,
#   0.0,
#   0,
#   90,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   10,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Poco nuboso',
#   21,
#   21,
#   15.0,
#   0.0,
#   0,
#   91,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   10,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Muy nuboso',
#   21,
#   21,
#   17.0,
#   0.0,
#   0,
#   89,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'E',
#   11,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Poco nuboso',
#   21,
#   21,
#   18.0,
#   0.0,
#   0,
#   84,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'E',
#   12,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nuboso',
#   20,
#   20,
#   19.0,
#   0.0,
#   0,
#   86,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'E',
#   11,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Muy nuboso',
#   19,
#   19,
#   13.0,
#   0.0,
#   0,
#   85,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   13,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Poco nuboso',
#   19,
#   19,
#   12.0,
#   0.0,
#   0,
#   87,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   8,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Cielo despejado',
#   19,
#   19,
#   10.0,
#   0.0,
#   0,
#   90,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'N',
#   8,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nubes altas',
#   18,
#   18,
#   8.0,
#   0.0,
#   0,
#   90,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   6,
#   'alamo-el-id28004',
#   'alamo-el',
#   'id28004'),
#  ('Nuboso con tormenta y lluvia escasa',
#   25,
#   25,
#   18.0,
#   0.1,
#   0,
#   61,
#   '100',
#   0,
#   75,
#   'Riesgo',
#   'SE',
#   8,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Intervalos nubosos con lluvia escasa',
#   27,
#   28,
#   18.0,
#   0.1,
#   0,
#   55,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'E',
#   7,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cubierto',
#   28,
#   28,
#   21.0,
#   0.0,
#   0,
#   46,
#   '100',
#   0,
#   80,
#   'Riesgo',
#   'E',
#   5,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cubierto',
#   29,
#   29,
#   35.0,
#   0.0,
#   0,
#   42,
#   'Riesgo',
#   0,
#   80,
#   'Riesgo',
#   'S',
#   8,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Nubes altas',
#   27,
#   27,
#   37.0,
#   0.0,
#   0,
#   49,
#   'Riesgo',
#   0,
#   80,
#   'Riesgo',
#   'S',
#   21,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Poco nuboso',
#   26,
#   26,
#   30.0,
#   0.0,
#   0,
#   47,
#   'Riesgo',
#   0,
#   80,
#   'Riesgo',
#   'S',
#   22,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cubierto',
#   27,
#   27,
#   30.0,
#   0.0,
#   0,
#   42,
#   'Riesgo',
#   0,
#   80,
#   'Riesgo',
#   'S',
#   15,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Intervalos nubosos con lluvia escasa',
#   25,
#   25,
#   21.0,
#   0.8,
#   0,
#   46,
#   'Riesgo',
#   0,
#   80,
#   'Riesgo',
#   'S',
#   16,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Muy nuboso',
#   23,
#   23,
#   18.0,
#   0.0,
#   0,
#   68,
#   '80',
#   0,
#   70,
#   'Riesgo',
#   'NE',
#   12,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cubierto',
#   22,
#   22,
#   24.0,
#   0.0,
#   0,
#   77,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'N',
#   9,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cubierto con tormenta',
#   21,
#   21,
#   38.0,
#   6.0,
#   0,
#   88,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'N',
#   9,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Muy nuboso',
#   20,
#   20,
#   38.0,
#   0.0,
#   0,
#   96,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'NE',
#   17,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Poco nuboso',
#   19,
#   19,
#   36.0,
#   0.0,
#   0,
#   97,
#   'Riesgo',
#   0,
#   70,
#   'Sin riesgo',
#   'E',
#   10,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cielo despejado',
#   19,
#   19,
#   22.0,
#   0.0,
#   0,
#   97,
#   'Riesgo',
#   0,
#   70,
#   'Sin riesgo',
#   'E',
#   18,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Poco nuboso',
#   18,
#   18,
#   29.0,
#   0.0,
#   0,
#   100,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   15,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Nuboso',
#   18,
#   18,
#   24.0,
#   0.0,
#   0,
#   100,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'N',
#   19,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Muy nuboso',
#   18,
#   18,
#   18.0,
#   0.0,
#   0,
#   100,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   15,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cielo despejado',
#   18,
#   18,
#   19.0,
#   0.0,
#   0,
#   100,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   12,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Nuboso',
#   18,
#   18,
#   21.0,
#   0.0,
#   0,
#   100,
#   'Riesgo',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   13,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Poco nuboso',
#   18,
#   18,
#   15.0,
#   0.0,
#   0,
#   100,
#   'Riesgo',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   14,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cubierto',
#   17,
#   17,
#   23.0,
#   0.0,
#   0,
#   100,
#   '25',
#   0,
#   25,
#   'Riesgo',
#   'NE',
#   9,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Muy nuboso',
#   20,
#   20,
#   16.0,
#   0.0,
#   0,
#   94,
#   'Riesgo',
#   0,
#   25,
#   'Riesgo',
#   'NE',
#   14,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cubierto',
#   22,
#   22,
#   30.0,
#   0.0,
#   0,
#   85,
#   'Riesgo',
#   0,
#   25,
#   'Riesgo',
#   'NE',
#   8,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Muy nuboso',
#   24,
#   24,
#   35.0,
#   0.0,
#   0,
#   77,
#   'Riesgo',
#   0,
#   25,
#   'Riesgo',
#   'SE',
#   20,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Nubes altas',
#   26,
#   26,
#   34.0,
#   0.0,
#   0,
#   58,
#   'Riesgo',
#   0,
#   25,
#   'Riesgo',
#   'E',
#   23,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Nubes altas',
#   27,
#   28,
#   31.0,
#   0.0,
#   0,
#   56,
#   'Riesgo',
#   0,
#   25,
#   'Riesgo',
#   'NO',
#   22,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Muy nuboso',
#   28,
#   29,
#   25.0,
#   0.0,
#   0,
#   51,
#   '60',
#   0,
#   60,
#   'Riesgo',
#   'N',
#   15,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cubierto',
#   29,
#   30,
#   19.0,
#   0.0,
#   0,
#   56,
#   'Riesgo',
#   0,
#   60,
#   'Riesgo',
#   'NE',
#   14,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Intervalos nubosos con lluvia escasa',
#   30,
#   31,
#   20.0,
#   0.1,
#   0,
#   50,
#   'Riesgo',
#   0,
#   60,
#   'Sin riesgo',
#   'NE',
#   10,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cubierto',
#   31,
#   33,
#   14.0,
#   0.0,
#   0,
#   52,
#   'Riesgo',
#   0,
#   60,
#   'Sin riesgo',
#   'NE',
#   10,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Poco nuboso',
#   28,
#   29,
#   16.0,
#   0.0,
#   0,
#   52,
#   'Riesgo',
#   0,
#   60,
#   'Sin riesgo',
#   'E',
#   7,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cielo despejado',
#   26,
#   26,
#   17.0,
#   0.0,
#   0,
#   60,
#   'Riesgo',
#   0,
#   60,
#   'Sin riesgo',
#   'NE',
#   9,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Poco nuboso',
#   24,
#   24,
#   9.0,
#   0.0,
#   0,
#   75,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NE',
#   9,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Poco nuboso',
#   23,
#   23,
#   12.0,
#   0.0,
#   0,
#   85,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NE',
#   6,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Poco nuboso',
#   22,
#   22,
#   14.0,
#   0.0,
#   0,
#   90,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NE',
#   8,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cubierto',
#   21,
#   21,
#   15.0,
#   0.0,
#   0,
#   91,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'E',
#   10,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Muy nuboso',
#   21,
#   21,
#   10.0,
#   0.0,
#   0,
#   85,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'N',
#   8,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Muy nuboso',
#   20,
#   20,
#   9.0,
#   0.0,
#   0,
#   83,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'N',
#   6,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Nuboso',
#   19,
#   19,
#   11.0,
#   0.0,
#   0,
#   85,
#   '10',
#   0,
#   10,
#   'Sin riesgo',
#   'NE',
#   3,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Poco nuboso',
#   19,
#   19,
#   14.0,
#   0.0,
#   0,
#   92,
#   '10',
#   0,
#   10,
#   'Sin riesgo',
#   'O',
#   2,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cielo despejado',
#   18,
#   18,
#   13.0,
#   0.0,
#   0,
#   91,
#   '10',
#   0,
#   10,
#   'Sin riesgo',
#   'NE',
#   8,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cielo despejado',
#   17,
#   17,
#   12.0,
#   0.0,
#   0,
#   99,
#   '10',
#   0,
#   10,
#   'Sin riesgo',
#   'NE',
#   9,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Poco nuboso',
#   17,
#   17,
#   10.0,
#   0.0,
#   0,
#   96,
#   '10',
#   0,
#   10,
#   'Sin riesgo',
#   'E',
#   5,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Nuboso',
#   17,
#   17,
#   10.0,
#   0.0,
#   0,
#   93,
#   '10',
#   0,
#   10,
#   'Sin riesgo',
#   'E',
#   7,
#   'alcala-de-henares-id28005',
#   'alcala-de-henares',
#   'id28005'),
#  ('Cubierto con lluvia escasa',
#   23,
#   23,
#   16.0,
#   0.1,
#   0,
#   65,
#   '95',
#   0,
#   70,
#   'Riesgo',
#   'E',
#   9,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cubierto con lluvia escasa',
#   25,
#   25,
#   19.0,
#   0.1,
#   0,
#   59,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'NE',
#   8,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Muy nuboso',
#   27,
#   28,
#   21.0,
#   0.0,
#   0,
#   52,
#   '100',
#   0,
#   75,
#   'Riesgo',
#   'E',
#   7,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Nubes altas',
#   27,
#   27,
#   13.0,
#   0.0,
#   0,
#   49,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'S',
#   10,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cubierto con tormenta y lluvia escasa',
#   28,
#   28,
#   50.0,
#   1.0,
#   0,
#   43,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'SO',
#   5,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cubierto con tormenta y lluvia escasa',
#   27,
#   28,
#   9.0,
#   1.0,
#   0,
#   61,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'S',
#   31,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Nubes altas',
#   25,
#   25,
#   61.0,
#   0.0,
#   0,
#   65,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'NO',
#   4,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Nuboso',
#   24,
#   24,
#   24.0,
#   0.0,
#   0,
#   51,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'NO',
#   24,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cubierto',
#   22,
#   22,
#   19.0,
#   0.0,
#   0,
#   62,
#   '80',
#   0,
#   65,
#   'Riesgo',
#   'NO',
#   15,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Nubes altas',
#   21,
#   21,
#   21.0,
#   0.0,
#   0,
#   68,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'N',
#   12,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cielo despejado',
#   21,
#   21,
#   22.0,
#   0.0,
#   0,
#   82,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'NE',
#   12,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Muy nuboso con lluvia escasa',
#   21,
#   21,
#   23.0,
#   0.1,
#   0,
#   82,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'N',
#   14,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cubierto',
#   20,
#   20,
#   16.0,
#   0.0,
#   0,
#   86,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'N',
#   14,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Intervalos nubosos con lluvia escasa',
#   20,
#   20,
#   24.0,
#   0.1,
#   0,
#   89,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'N',
#   10,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Poco nuboso',
#   19,
#   19,
#   34.0,
#   0.0,
#   0,
#   88,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'N',
#   15,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Muy nuboso',
#   19,
#   19,
#   27.0,
#   0.0,
#   0,
#   87,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'N',
#   18,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cubierto',
#   19,
#   19,
#   23.0,
#   0.0,
#   0,
#   89,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'NE',
#   17,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Nuboso',
#   19,
#   19,
#   24.0,
#   0.0,
#   0,
#   89,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'NE',
#   14,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cielo despejado',
#   19,
#   19,
#   25.0,
#   0.0,
#   0,
#   90,
#   'Riesgo',
#   0,
#   20,
#   'Sin riesgo',
#   'NE',
#   15,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cielo despejado',
#   18,
#   18,
#   19.0,
#   0.0,
#   0,
#   95,
#   'Riesgo',
#   0,
#   20,
#   'Sin riesgo',
#   'NE',
#   15,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cubierto',
#   18,
#   18,
#   23.0,
#   0.0,
#   0,
#   99,
#   '20',
#   0,
#   20,
#   'Riesgo',
#   'N',
#   11,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cubierto',
#   20,
#   20,
#   17.0,
#   0.0,
#   0,
#   89,
#   'Riesgo',
#   0,
#   20,
#   'Riesgo',
#   'NE',
#   14,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cubierto',
#   22,
#   22,
#   34.0,
#   0.0,
#   0,
#   83,
#   'Riesgo',
#   0,
#   20,
#   'Riesgo',
#   'E',
#   10,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cubierto',
#   24,
#   24,
#   14.0,
#   0.0,
#   0,
#   75,
#   'Riesgo',
#   0,
#   20,
#   'Riesgo',
#   'SE',
#   21,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cubierto',
#   25,
#   25,
#   30.0,
#   0.0,
#   0,
#   67,
#   'Riesgo',
#   0,
#   20,
#   'Riesgo',
#   'S',
#   3,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Nubes altas',
#   26,
#   26,
#   31.0,
#   0.0,
#   0,
#   56,
#   'Riesgo',
#   0,
#   20,
#   'Riesgo',
#   'C',
#   0,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cubierto',
#   28,
#   29,
#   25.0,
#   0.0,
#   0,
#   52,
#   '50',
#   0,
#   50,
#   'Riesgo',
#   'NE',
#   17,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Poco nuboso',
#   29,
#   29,
#   21.0,
#   0.0,
#   0,
#   47,
#   'Riesgo',
#   0,
#   50,
#   'Riesgo',
#   'NE',
#   14,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Poco nuboso',
#   29,
#   29,
#   23.0,
#   0.0,
#   0,
#   45,
#   'Riesgo',
#   0,
#   50,
#   'Sin riesgo',
#   'NE',
#   11,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Intervalos nubosos con lluvia escasa',
#   30,
#   30,
#   22.0,
#   0.1,
#   0,
#   45,
#   'Riesgo',
#   0,
#   50,
#   'Sin riesgo',
#   'NE',
#   11,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cielo despejado',
#   27,
#   28,
#   22.0,
#   0.0,
#   0,
#   59,
#   'Riesgo',
#   0,
#   50,
#   'Sin riesgo',
#   'NE',
#   12,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Poco nuboso',
#   23,
#   23,
#   20.0,
#   0.0,
#   0,
#   79,
#   'Riesgo',
#   0,
#   50,
#   'Sin riesgo',
#   'NE',
#   13,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Poco nuboso',
#   24,
#   24,
#   12.0,
#   0.0,
#   0,
#   76,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NE',
#   11,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Nubes altas',
#   23,
#   23,
#   17.0,
#   0.0,
#   0,
#   73,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NE',
#   7,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Nubes altas',
#   23,
#   23,
#   17.0,
#   0.0,
#   0,
#   79,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'N',
#   11,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Muy nuboso',
#   22,
#   22,
#   10.0,
#   0.0,
#   0,
#   87,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'N',
#   11,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Poco nuboso',
#   21,
#   21,
#   10.0,
#   0.0,
#   0,
#   85,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'E',
#   6,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cubierto',
#   21,
#   21,
#   12.0,
#   0.0,
#   0,
#   83,
#   '25',
#   0,
#   25,
#   'Sin riesgo',
#   'NE',
#   7,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Muy nuboso',
#   20,
#   20,
#   13.0,
#   0.0,
#   0,
#   86,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'NE',
#   8,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cubierto',
#   20,
#   20,
#   10.0,
#   0.0,
#   0,
#   87,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'E',
#   8,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cielo despejado',
#   19,
#   19,
#   15.0,
#   0.0,
#   0,
#   78,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'E',
#   5,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Muy nuboso',
#   19,
#   19,
#   20.0,
#   0.0,
#   0,
#   86,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'N',
#   10,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cielo despejado',
#   19,
#   19,
#   11.0,
#   0.0,
#   0,
#   90,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'N',
#   10,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Nubes altas',
#   18,
#   18,
#   5.0,
#   0.0,
#   0,
#   91,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'NE',
#   7,
#   'alcobendas-id28006',
#   'alcobendas',
#   'id28006'),
#  ('Cubierto con lluvia escasa',
#   23,
#   23,
#   19.0,
#   0.1,
#   0,
#   68,
#   '85',
#   0,
#   65,
#   'Riesgo',
#   'E',
#   10,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Intervalos nubosos con lluvia escasa',
#   24,
#   24,
#   19.0,
#   0.1,
#   0,
#   60,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'E',
#   9,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Nuboso con lluvia escasa',
#   25,
#   25,
#   18.0,
#   0.1,
#   0,
#   55,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'E',
#   8,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Nubes altas',
#   26,
#   26,
#   21.0,
#   0.0,
#   0,
#   49,
#   '100',
#   0,
#   70,
#   'Riesgo',
#   'SE',
#   8,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Cubierto',
#   27,
#   27,
#   18.0,
#   0.0,
#   0,
#   46,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'SE',
#   10,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Cubierto',
#   27,
#   27,
#   46.0,
#   0.0,
#   0,
#   44,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'SE',
#   7,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Cubierto',
#   28,
#   28,
#   15.0,
#   0.0,
#   0,
#   47,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'SE',
#   22,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Intervalos nubosos con lluvia escasa',
#   25,
#   25,
#   19.0,
#   0.8,
#   0,
#   52,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'C',
#   0,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Nuboso',
#   22,
#   22,
#   21.0,
#   0.0,
#   0,
#   72,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'NE',
#   12,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Intervalos nubosos con lluvia escasa',
#   20,
#   20,
#   17.0,
#   0.1,
#   0,
#   81,
#   '75',
#   0,
#   70,
#   'Riesgo',
#   'N',
#   11,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Cubierto con lluvia escasa',
#   20,
#   20,
#   25.0,
#   0.1,
#   0,
#   77,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'E',
#   11,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Cubierto con lluvia escasa',
#   18,
#   18,
#   28.0,
#   0.1,
#   0,
#   78,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'NE',
#   15,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Nuboso con lluvia escasa',
#   19,
#   19,
#   23.0,
#   0.1,
#   0,
#   81,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'NE',
#   18,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Intervalos nubosos con lluvia escasa',
#   18,
#   18,
#   28.0,
#   0.1,
#   0,
#   86,
#   'Riesgo',
#   0,
#   70,
#   'Sin riesgo',
#   'NE',
#   13,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Intervalos nubosos con lluvia escasa',
#   18,
#   18,
#   30.0,
#   0.1,
#   0,
#   91,
#   'Riesgo',
#   0,
#   70,
#   'Sin riesgo',
#   'NE',
#   17,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Muy nuboso',
#   18,
#   18,
#   36.0,
#   0.0,
#   0,
#   95,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   19,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Muy nuboso',
#   18,
#   18,
#   30.0,
#   0.0,
#   0,
#   90,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   22,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Nuboso',
#   18,
#   18,
#   30.0,
#   0.0,
#   0,
#   89,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   19,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Poco nuboso',
#   18,
#   18,
#   27.0,
#   0.0,
#   0,
#   87,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   18,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Cielo despejado',
#   18,
#   18,
#   26.0,
#   0.0,
#   0,
#   91,
#   'Riesgo',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   16,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Poco nuboso',
#   17,
#   17,
#   26.0,
#   0.0,
#   0,
#   94,
#   'Riesgo',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   16,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Poco nuboso',
#   17,
#   17,
#   26.0,
#   0.0,
#   0,
#   100,
#   '20',
#   0,
#   20,
#   'Riesgo',
#   'NE',
#   16,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Cubierto',
#   19,
#   19,
#   26.0,
#   0.0,
#   0,
#   90,
#   'Riesgo',
#   0,
#   20,
#   'Riesgo',
#   'NE',
#   15,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Cubierto',
#   21,
#   21,
#   32.0,
#   0.0,
#   0,
#   80,
#   'Riesgo',
#   0,
#   20,
#   'Riesgo',
#   'E',
#   16,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Cubierto',
#   23,
#   23,
#   39.0,
#   0.0,
#   0,
#   77,
#   'Riesgo',
#   0,
#   20,
#   'Riesgo',
#   'E',
#   16,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Cubierto',
#   25,
#   25,
#   40.0,
#   0.0,
#   0,
#   68,
#   'Riesgo',
#   0,
#   20,
#   'Riesgo',
#   'E',
#   25,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Nubes altas',
#   26,
#   26,
#   32.0,
#   0.0,
#   0,
#   60,
#   'Riesgo',
#   0,
#   20,
#   'Riesgo',
#   'N',
#   18,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Muy nuboso con lluvia escasa',
#   27,
#   28,
#   33.0,
#   0.1,
#   0,
#   54,
#   '55',
#   0,
#   55,
#   'Riesgo',
#   'NE',
#   16,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Muy nuboso con lluvia escasa',
#   28,
#   29,
#   30.0,
#   0.1,
#   0,
#   52,
#   'Riesgo',
#   0,
#   55,
#   'Riesgo',
#   'NE',
#   18,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Intervalos nubosos con lluvia escasa',
#   28,
#   28,
#   28.0,
#   0.1,
#   0,
#   44,
#   'Riesgo',
#   0,
#   55,
#   'Sin riesgo',
#   'NE',
#   16,
#   'alcorcon-id28007',
#   'alcorcon',
#   'id28007'),
#  ('Intervalos nubosos con lluvia escasa',
#   29,
#   29,
#   27.0,
#   0.1,
#   0,
#   43,
#   'Riesgo',
#   0,
#   55,
#   'Sin riesgo',
#   'NE',
#   16,
#   'alcorcon-id28007',
# ...
#   'Riesgo',
#   'S',
#   15,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Cubierto con lluvia',
#   23,
#   23,
#   12.0,
#   7.0,
#   0,
#   67,
#   'Riesgo',
#   0,
#   50,
#   'Riesgo',
#   'SE',
#   24,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Cubierto con lluvia escasa',
#   25,
#   25,
#   20.0,
#   2.0,
#   0,
#   57,
#   'Riesgo',
#   0,
#   50,
#   'Riesgo',
#   'S',
#   7,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Nuboso',
#   26,
#   26,
#   16.0,
#   0.0,
#   0,
#   49,
#   '65',
#   0,
#   65,
#   'Riesgo',
#   'N',
#   12,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Nubes altas',
#   27,
#   27,
#   12.0,
#   0.0,
#   0,
#   44,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'NE',
#   8,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Nubes altas',
#   27,
#   27,
#   14.0,
#   0.0,
#   0,
#   40,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'O',
#   5,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Nubes altas',
#   27,
#   27,
#   19.0,
#   0.0,
#   0,
#   39,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'SO',
#   6,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Intervalos nubosos con lluvia escasa',
#   26,
#   26,
#   19.0,
#   0.1,
#   0,
#   40,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'S',
#   10,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Poco nuboso',
#   25,
#   25,
#   13.0,
#   0.0,
#   0,
#   51,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'S',
#   11,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Nubes altas',
#   23,
#   23,
#   5.0,
#   0.0,
#   0,
#   60,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'S',
#   6,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Cielo despejado',
#   21,
#   21,
#   9.0,
#   0.0,
#   0,
#   72,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'NE',
#   4,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Poco nuboso',
#   20,
#   20,
#   5.0,
#   0.0,
#   0,
#   76,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'E',
#   6,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Cubierto',
#   18,
#   18,
#   5.0,
#   0.0,
#   0,
#   82,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'E',
#   3,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Nuboso',
#   17,
#   17,
#   3.0,
#   0.0,
#   0,
#   87,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'SO',
#   3,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Nuboso',
#   17,
#   17,
#   11.0,
#   0.0,
#   0,
#   93,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'SE',
#   2,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Cielo despejado',
#   17,
#   17,
#   10.0,
#   0.0,
#   0,
#   87,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'E',
#   7,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Poco nuboso',
#   16,
#   16,
#   15.0,
#   0.0,
#   0,
#   82,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'SE',
#   7,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Poco nuboso',
#   15,
#   15,
#   6.0,
#   0.0,
#   0,
#   89,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'E',
#   6,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Cielo despejado',
#   14,
#   14,
#   6.0,
#   0.0,
#   0,
#   96,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'NE',
#   4,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Cielo despejado',
#   15,
#   15,
#   9.0,
#   0.0,
#   0,
#   89,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'NE',
#   5,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Nubes altas',
#   14,
#   14,
#   11.0,
#   0.0,
#   0,
#   92,
#   '0',
#   0,
#   0,
#   'Sin riesgo',
#   'NE',
#   7,
#   'berzosa-del-lozoya-id28020',
#   'berzosa-del-lozoya',
#   'id28020'),
#  ('Intervalos nubosos con lluvia escasa',
#   24,
#   24,
#   21.0,
#   0.1,
#   0,
#   59,
#   '80',
#   0,
#   65,
#   'Riesgo',
#   'E',
#   9,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Cubierto con lluvia escasa',
#   25,
#   25,
#   19.0,
#   0.1,
#   0,
#   54,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'E',
#   9,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Nuboso',
#   27,
#   27,
#   22.0,
#   0.0,
#   0,
#   47,
#   '100',
#   0,
#   65,
#   'Riesgo',
#   'SE',
#   8,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Cubierto',
#   26,
#   26,
#   19.0,
#   0.0,
#   0,
#   46,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'S',
#   10,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Cubierto',
#   27,
#   27,
#   41.0,
#   0.0,
#   0,
#   43,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'SE',
#   8,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Cubierto con lluvia escasa',
#   28,
#   28,
#   54.0,
#   0.1,
#   0,
#   44,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'SE',
#   25,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Intervalos nubosos con lluvia',
#   25,
#   25,
#   25.0,
#   4.0,
#   0,
#   59,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'O',
#   34,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Cubierto',
#   23,
#   23,
#   25.0,
#   0.0,
#   0,
#   73,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'NE',
#   14,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Cubierto con lluvia escasa',
#   20,
#   20,
#   16.0,
#   0.1,
#   0,
#   82,
#   '75',
#   0,
#   65,
#   'Riesgo',
#   'N',
#   13,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Muy nuboso',
#   21,
#   21,
#   20.0,
#   0.0,
#   0,
#   83,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'NE',
#   10,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Nuboso',
#   18,
#   18,
#   32.0,
#   0.0,
#   0,
#   83,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'NE',
#   13,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Nuboso',
#   19,
#   19,
#   30.0,
#   0.0,
#   0,
#   81,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'NE',
#   21,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Muy nuboso',
#   18,
#   18,
#   36.0,
#   0.0,
#   0,
#   85,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'NE',
#   18,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Muy nuboso',
#   18,
#   18,
#   27.0,
#   0.0,
#   0,
#   90,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'NE',
#   23,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Poco nuboso',
#   18,
#   18,
#   38.0,
#   0.0,
#   0,
#   92,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   14,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Cubierto',
#   18,
#   18,
#   30.0,
#   0.0,
#   0,
#   91,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   25,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Muy nuboso',
#   18,
#   18,
#   31.0,
#   0.0,
#   0,
#   91,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   20,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Cubierto',
#   18,
#   18,
#   29.0,
#   0.0,
#   0,
#   90,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   20,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Poco nuboso',
#   18,
#   18,
#   30.0,
#   0.0,
#   0,
#   94,
#   'Riesgo',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   19,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Cielo despejado',
#   17,
#   17,
#   29.0,
#   0.0,
#   0,
#   95,
#   'Riesgo',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   20,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Nuboso',
#   17,
#   17,
#   26.0,
#   0.0,
#   0,
#   100,
#   '20',
#   0,
#   20,
#   'Riesgo',
#   'NE',
#   19,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Muy nuboso',
#   19,
#   19,
#   24.0,
#   0.0,
#   0,
#   91,
#   'Riesgo',
#   0,
#   20,
#   'Riesgo',
#   'NE',
#   17,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Cubierto',
#   22,
#   22,
#   27.0,
#   0.0,
#   0,
#   81,
#   'Riesgo',
#   0,
#   20,
#   'Riesgo',
#   'E',
#   15,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Cubierto',
#   24,
#   24,
#   50.0,
#   0.0,
#   0,
#   76,
#   'Riesgo',
#   0,
#   20,
#   'Riesgo',
#   'E',
#   15,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Nuboso',
#   25,
#   25,
#   48.0,
#   0.0,
#   0,
#   67,
#   'Riesgo',
#   0,
#   20,
#   'Riesgo',
#   'E',
#   34,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Nubes altas',
#   26,
#   26,
#   34.0,
#   0.0,
#   0,
#   60,
#   'Riesgo',
#   0,
#   20,
#   'Riesgo',
#   'N',
#   27,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Muy nuboso',
#   27,
#   28,
#   31.0,
#   0.0,
#   0,
#   53,
#   '55',
#   0,
#   55,
#   'Riesgo',
#   'NE',
#   19,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Muy nuboso',
#   28,
#   28,
#   29.0,
#   0.0,
#   0,
#   50,
#   'Riesgo',
#   0,
#   55,
#   'Riesgo',
#   'NE',
#   18,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Nubes altas',
#   29,
#   29,
#   26.0,
#   0.0,
#   0,
#   44,
#   'Riesgo',
#   0,
#   55,
#   'Sin riesgo',
#   'E',
#   18,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Poco nuboso',
#   30,
#   30,
#   26.0,
#   0.0,
#   0,
#   43,
#   'Riesgo',
#   0,
#   55,
#   'Sin riesgo',
#   'NE',
#   16,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Cielo despejado',
#   27,
#   27,
#   25.0,
#   0.0,
#   0,
#   50,
#   'Riesgo',
#   0,
#   55,
#   'Sin riesgo',
#   'NE',
#   16,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Intervalos nubosos con lluvia escasa',
#   25,
#   25,
#   19.0,
#   0.1,
#   0,
#   60,
#   'Riesgo',
#   0,
#   55,
#   'Sin riesgo',
#   'NE',
#   15,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Poco nuboso',
#   23,
#   23,
#   20.0,
#   0.0,
#   0,
#   73,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'NE',
#   12,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Nubes altas',
#   23,
#   23,
#   24.0,
#   0.0,
#   0,
#   81,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'E',
#   10,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Nubes altas',
#   21,
#   21,
#   23.0,
#   0.0,
#   0,
#   84,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'NE',
#   16,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Cielo despejado',
#   20,
#   20,
#   21.0,
#   0.0,
#   0,
#   89,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'NE',
#   14,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Poco nuboso',
#   20,
#   20,
#   20.0,
#   0.0,
#   0,
#   92,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'E',
#   14,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Muy nuboso',
#   19,
#   19,
#   16.0,
#   0.0,
#   0,
#   92,
#   '20',
#   0,
#   20,
#   'Sin riesgo',
#   'NE',
#   13,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Muy nuboso',
#   19,
#   19,
#   21.0,
#   0.0,
#   0,
#   89,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   10,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Muy nuboso',
#   19,
#   19,
#   11.0,
#   0.0,
#   0,
#   86,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'E',
#   14,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Cielo despejado',
#   19,
#   19,
#   23.0,
#   0.0,
#   0,
#   84,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   8,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Cielo despejado',
#   18,
#   18,
#   16.0,
#   0.0,
#   0,
#   86,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   15,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Poco nuboso',
#   18,
#   18,
#   13.0,
#   0.0,
#   0,
#   85,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   9,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Nubes altas',
#   18,
#   18,
#   14.0,
#   0.0,
#   0,
#   88,
#   '5',
#   0,
#   5,
#   'Sin riesgo',
#   'NE',
#   8,
#   'boadilla-del-monte-id28022',
#   'boadilla-del-monte',
#   'id28022'),
#  ('Nubes altas',
#   23,
#   23,
#   27.0,
#   0.0,
#   0,
#   67,
#   '90',
#   0,
#   70,
#   'Riesgo',
#   'E',
#   13,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Cubierto',
#   25,
#   25,
#   23.0,
#   0.0,
#   0,
#   56,
#   'Riesgo',
#   0,
#   70,
#   'Riesgo',
#   'E',
#   14,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Nuboso',
#   25,
#   25,
#   25.0,
#   0.0,
#   0,
#   55,
#   '100',
#   0,
#   75,
#   'Riesgo',
#   'SE',
#   11,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Muy nuboso',
#   23,
#   23,
#   23.0,
#   0.0,
#   0,
#   62,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'SE',
#   13,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Muy nuboso',
#   26,
#   26,
#   25.0,
#   0.0,
#   0,
#   49,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'SE',
#   12,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Cubierto',
#   25,
#   25,
#   41.0,
#   0.0,
#   0,
#   48,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'S',
#   13,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Nuboso',
#   26,
#   26,
#   38.0,
#   0.0,
#   0,
#   53,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'SE',
#   23,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Nuboso con tormenta y lluvia escasa',
#   20,
#   20,
#   7.0,
#   0.1,
#   0,
#   57,
#   'Riesgo',
#   0,
#   75,
#   'Riesgo',
#   'SE',
#   10,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Cubierto',
#   20,
#   20,
#   9.0,
#   0.0,
#   0,
#   53,
#   '75',
#   0,
#   65,
#   'Riesgo',
#   'N',
#   4,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Nubes altas',
#   19,
#   19,
#   6.0,
#   0.0,
#   0,
#   58,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'S',
#   3,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Nuboso',
#   19,
#   19,
#   12.0,
#   0.0,
#   0,
#   65,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'NO',
#   4,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Intervalos nubosos con lluvia escasa',
#   18,
#   18,
#   14.0,
#   0.1,
#   0,
#   71,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'E',
#   5,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Nuboso',
#   17,
#   17,
#   21.0,
#   0.0,
#   0,
#   74,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'E',
#   8,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Nuboso',
#   17,
#   17,
#   8.0,
#   0.0,
#   0,
#   82,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'E',
#   12,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Poco nuboso',
#   16,
#   16,
#   15.0,
#   0.0,
#   0,
#   79,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'SE',
#   6,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Muy nuboso',
#   16,
#   16,
#   13.0,
#   0.0,
#   0,
#   82,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'E',
#   9,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Muy nuboso',
#   17,
#   17,
#   21.0,
#   0.0,
#   0,
#   87,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'E',
#   9,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Nuboso',
#   17,
#   17,
#   22.0,
#   0.0,
#   0,
#   84,
#   '15',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   14,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Nuboso',
#   17,
#   17,
#   24.0,
#   0.0,
#   0,
#   90,
#   'Riesgo',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   14,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Cielo despejado',
#   17,
#   17,
#   20.0,
#   0.0,
#   0,
#   94,
#   'Riesgo',
#   0,
#   15,
#   'Sin riesgo',
#   'NE',
#   15,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Cielo despejado',
#   17,
#   17,
#   18.0,
#   0.0,
#   0,
#   99,
#   '55',
#   0,
#   55,
#   'Riesgo',
#   'NE',
#   13,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Poco nuboso',
#   19,
#   19,
#   26.0,
#   0.0,
#   0,
#   90,
#   'Riesgo',
#   0,
#   55,
#   'Riesgo',
#   'E',
#   11,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Cubierto',
#   20,
#   20,
#   30.0,
#   0.0,
#   0,
#   81,
#   'Riesgo',
#   0,
#   55,
#   'Riesgo',
#   'E',
#   14,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Cubierto con lluvia escasa',
#   22,
#   22,
#   28.0,
#   1.0,
#   0,
#   74,
#   'Riesgo',
#   0,
#   55,
#   'Riesgo',
#   'E',
#   18,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Cubierto con lluvia',
#   24,
#   24,
#   37.0,
#   29.0,
#   0,
#   76,
#   'Riesgo',
#   0,
#   55,
#   'Riesgo',
#   'E',
#   18,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Intervalos nubosos con lluvia',
#   25,
#   25,
#   15.0,
#   4.0,
#   0,
#   55,
#   'Riesgo',
#   0,
#   55,
#   'Riesgo',
#   'N',
#   10,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Nubes altas',
#   27,
#   27,
#   13.0,
#   0.0,
#   0,
#   49,
#   '65',
#   0,
#   65,
#   'Riesgo',
#   'SE',
#   10,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Intervalos nubosos con lluvia escasa',
#   27,
#   27,
#   12.0,
#   0.1,
#   0,
#   47,
#   'Riesgo',
#   0,
#   65,
#   'Riesgo',
#   'E',
#   5,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Intervalos nubosos con lluvia escasa',
#   28,
#   28,
#   15.0,
#   0.1,
#   0,
#   44,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'E',
#   5,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ('Poco nuboso',
#   28,
#   28,
#   18.0,
#   0.0,
#   0,
#   45,
#   'Riesgo',
#   0,
#   65,
#   'Sin riesgo',
#   'E',
#   6,
#   'boalo-el-id28023',
#   'boalo-el',
#   'id28023'),
#  ...]

# %%
try:
    conexion = psycopg2.connect(
    database = 'Productora',
    user = 'postgres',
    password = 'admin',
    host = 'localhost',
    port = '5432')
except OperationalError as e: #el alias es e
    if e.pgcode == errorcodes.INVALID_PASSWORD:
        print('la contraseña es erronea')
    elif e.pgcode == errorcodes.CONNECTION_EXCEPTION:
        print('error de conexion')
    else:
        print(f'el error es el siguiente {e}')

# %%
cursor = conexion.cursor() #para crear la tabla desde aquí
query_creacion = """ 
    CREATE TABLE IF NOT EXISTS municipios (
    id_municipio SERIAL PRIMARY KEY,
    lat float,
    long float);

"""

# %%
cursor = conexion.cursor() #para crear la tabla desde aquí
query_creacion = """ 
    CREATE TABLE IF NOT EXISTS AEMET (
    id_municipio SERIAL PRIMARY KEY,
    lat float,
    long float,
    );

"""

# %%
cursor.execute(query_creacion)
conexion.commit()

query_insercion = 'INSERT INTO clientes (nombre, edad) VALUES (%s, %s)' # insertar valores %s es como un formato. como un argumento
valores = ('PEPE', 19)
cursor.execute(query_insercion, valores)
conexion.commit()
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# Cell In[26], line 6
#       4 query_insercion = 'INSERT INTO clientes (nombre, edad) VALUES (%s, %s)' # insertar valores %s es como un formato. como un argumento
#       5 valores = ('PEPE', 19)
# ----> 6 cursor.execute(query_insercion, valores)
#       7 conexion.commit()
#
# UndefinedTable: no existe la relación «clientes»
# LINE 1: INSERT INTO clientes (nombre, edad) VALUES ('PEPE', 19)
#                     ^

# %%
# Sacar nombre, tipo, ciudad,state,street
listadict = []
for i in range(0,len(respuesta1)):
    nombre = respuesta1[i]["name"]
    tipo = respuesta1[i]["brewery_type"]
    ciudad = respuesta1[i]["city"]
    estado = respuesta1[i]["state"]
    calle = respuesta1[i]["street"]
    diccionario = {
        "name":nombre,
        "brewery_type":tipo,
        "city":ciudad,
        "state":estado,
        "street":calle
    }
    listadict.append(diccionario)

df_limpio = pd.DataFrame(listadict)
df_limpio
# Out:
# Index([0, 1, 2], dtype='int64')
